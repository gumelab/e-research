# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/EtiquetasYoutube/Youtube_IM,FP,CH_22.12.22.xlsx'

# %%
fp=pd.read_excel(path,sheet_name=0)

# %%
im=pd.read_excel(path,sheet_name=1)

# %%
ch=pd.read_excel(path,sheet_name=2)

# %%
no=pd.read_excel(path,sheet_name=3)

# %%
fp
# Out:
#                         idVideo  \
# 0                   NS8JbFvuTb4
# 1                   NS8JbFvuTb4
# 2                   ADuMNEja1dQ
# 3                   ADuMNEja1dQ
# 4                   ADuMNEja1dQ
# ..                          ...
# 186  UgxTOpdUMCc0_7Auufx4AaABAg
# 187  UgxTOpdUMCc0_7Auufx4AaABAg
# 188  UgxTOpdUMCc0_7Auufx4AaABAg
# 189        UggiWJ9x2DFk4HgCoAEC
# 190  UgzJP-AAUqRBg6H3-_14AaABAg
#
#                                  idComentarioPrincipal  \
# 0                           UgzCxWFNA6dZNLaMVHF4AaABAg
# 1                                 UggpDwdh_GoZr3gCoAEC
# 2                           Ugy_RESn29HxbpDRXEJ4AaABAg
# 3                           UgyOlKnh4tJskh71ECR4AaABAg
# 4                           UgxCYvuiNtos_RZ_GFZ4AaABAg
# ..                                                 ...
# 186  UgxTOpdUMCc0_7Auufx4AaABAg.8XmV9ZVPYYH8YPN6pvxHxN
# 187  UgxTOpdUMCc0_7Auufx4AaABAg.8XmV9ZVPYYH8Xqq-xbbIVO
# 188  UgxTOpdUMCc0_7Auufx4AaABAg.8XmV9ZVPYYH8XqpBUev4jX
# ...

# %%
im
# Out:
#          idVideo       idComentarioPrincipal  \
# 0    fhb3Ms3Mj8s  UgzhOuz_gV7AG6n-gqB4AaABAg
# 1    fhb3Ms3Mj8s  UgyX63qpkYN0jA8a0OJ4AaABAg
# 2    fhb3Ms3Mj8s  Ugw1V9tECDUchWT3unB4AaABAg
# 3    fhb3Ms3Mj8s  UgzMPVkU8XFDbb8ciDV4AaABAg
# 4    41c8e5JrDwQ  UgzRR0r0Q6DPP0nyct54AaABAg
# ..           ...                         ...
# 168  sUMU9Nul86o  Ugzd0wtQAl_srx1q5054AaABAg
# 169  sUMU9Nul86o  UgxnW_YumRIBdXeYoLh4AaABAg
# 170  sUMU9Nul86o  UgzzGqMDa2ni2RqjyAV4AaABAg
# 171  sUMU9Nul86o  UgwNY9oD7VlbpjJwVfd4AaABAg
# 172  sUMU9Nul86o  Ugy4BrfhYn1snws-Z7B4AaABAg
#
#                               TextoComentarioPrincipal IM, FP, CH  \
# 0    Ese 1tres de agosto de 1999 nos mataron un poc...         IM
# 1    Jaime Garzón era un humorista Colombiano que s...         IM
# 2    Jaime!!! Cuanta razon tenias y cuan indiferent...         IM
# 3    para todos los presentes jairo garcia es JAIME...         IM
# 4    Sr Campeche historiador Hoy van en el capítulo...         IM
# ...

# %%
ch
# Out:
#                         idVideo  \
# 0                   ADuMNEja1dQ
# 1                   NNZI4hX_4rM
# 2                   NNZI4hX_4rM
# 3                   ofjZvLSudxo
# 4                   ofjZvLSudxo
# ..                          ...
# 136  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 137  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 138  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 139        UgjdNZjbN4cMRXgCoAEC
# 140        UgjdNZjbN4cMRXgCoAEC
#
#                                  idComentarioPrincipal  \
# 0                           UgzgDoJ9XU6RaBnLs9Z4AaABAg
# 1                           UgwcL7GOp6tw0tsFuON4AaABAg
# 2                           Ugy4ZgHW1Jhl6rxNMYt4AaABAg
# 3                           Ugzmu9E3ElYLssnHWyV4AaABAg
# 4                           UgyfUobYNrLXp3khStJ4AaABAg
# ..                                                 ...
# 136  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9PdHDZ0J_Ow
# 137  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9PdE_ak_kuK
# 138  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9Oh40ulZWrn
# ...

# %%
fp=fp[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]
im=im[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]
ch=ch[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]
no=no[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]

# %%
fp
# Out:
#                         idVideo  \
# 0                   NS8JbFvuTb4
# 1                   NS8JbFvuTb4
# 2                   ADuMNEja1dQ
# 3                   ADuMNEja1dQ
# 4                   ADuMNEja1dQ
# ..                          ...
# 186  UgxTOpdUMCc0_7Auufx4AaABAg
# 187  UgxTOpdUMCc0_7Auufx4AaABAg
# 188  UgxTOpdUMCc0_7Auufx4AaABAg
# 189        UggiWJ9x2DFk4HgCoAEC
# 190  UgzJP-AAUqRBg6H3-_14AaABAg
#
#                                  idComentarioPrincipal  \
# 0                           UgzCxWFNA6dZNLaMVHF4AaABAg
# 1                                 UggpDwdh_GoZr3gCoAEC
# 2                           Ugy_RESn29HxbpDRXEJ4AaABAg
# 3                           UgyOlKnh4tJskh71ECR4AaABAg
# 4                           UgxCYvuiNtos_RZ_GFZ4AaABAg
# ..                                                 ...
# 186  UgxTOpdUMCc0_7Auufx4AaABAg.8XmV9ZVPYYH8YPN6pvxHxN
# 187  UgxTOpdUMCc0_7Auufx4AaABAg.8XmV9ZVPYYH8Xqq-xbbIVO
# 188  UgxTOpdUMCc0_7Auufx4AaABAg.8XmV9ZVPYYH8XqpBUev4jX
# ...

# %%
im
# Out:
#          idVideo       idComentarioPrincipal  \
# 0    fhb3Ms3Mj8s  UgzhOuz_gV7AG6n-gqB4AaABAg
# 1    fhb3Ms3Mj8s  UgyX63qpkYN0jA8a0OJ4AaABAg
# 2    fhb3Ms3Mj8s  Ugw1V9tECDUchWT3unB4AaABAg
# 3    fhb3Ms3Mj8s  UgzMPVkU8XFDbb8ciDV4AaABAg
# 4    41c8e5JrDwQ  UgzRR0r0Q6DPP0nyct54AaABAg
# ..           ...                         ...
# 168  sUMU9Nul86o  Ugzd0wtQAl_srx1q5054AaABAg
# 169  sUMU9Nul86o  UgxnW_YumRIBdXeYoLh4AaABAg
# 170  sUMU9Nul86o  UgzzGqMDa2ni2RqjyAV4AaABAg
# 171  sUMU9Nul86o  UgwNY9oD7VlbpjJwVfd4AaABAg
# 172  sUMU9Nul86o  Ugy4BrfhYn1snws-Z7B4AaABAg
#
#                               TextoComentarioPrincipal IM, FP, CH
# 0    Ese 1tres de agosto de 1999 nos mataron un poc...         IM
# 1    Jaime Garzón era un humorista Colombiano que s...         IM
# 2    Jaime!!! Cuanta razon tenias y cuan indiferent...         IM
# 3    para todos los presentes jairo garcia es JAIME...         IM
# 4    Sr Campeche historiador Hoy van en el capítulo...         IM
# ...

# %%
ch
# Out:
#                         idVideo  \
# 0                   ADuMNEja1dQ
# 1                   NNZI4hX_4rM
# 2                   NNZI4hX_4rM
# 3                   ofjZvLSudxo
# 4                   ofjZvLSudxo
# ..                          ...
# 136  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 137  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 138  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 139        UgjdNZjbN4cMRXgCoAEC
# 140        UgjdNZjbN4cMRXgCoAEC
#
#                                  idComentarioPrincipal  \
# 0                           UgzgDoJ9XU6RaBnLs9Z4AaABAg
# 1                           UgwcL7GOp6tw0tsFuON4AaABAg
# 2                           Ugy4ZgHW1Jhl6rxNMYt4AaABAg
# 3                           Ugzmu9E3ElYLssnHWyV4AaABAg
# 4                           UgyfUobYNrLXp3khStJ4AaABAg
# ..                                                 ...
# 136  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9PdHDZ0J_Ow
# 137  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9PdE_ak_kuK
# 138  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9Oh40ulZWrn
# ...

# %%
no=no.iloc[0:200]

# %%
no
# Out:
#                         idVideo  \
# 0                   i_6E10appCA
# 1                   i_6E10appCA
# 2                   i_6E10appCA
# 3                   i_6E10appCA
# 4                   i_6E10appCA
# ..                          ...
# 195  UgxtZYWotCV2o7JV3eR4AaABAg
# 196  Ugxgw_CVAAlmMor6drB4AaABAg
# 197  Ugwk1ZeFRVbZsvs9W-Z4AaABAg
# 198  UgwJvMCt6dE5h1e53K14AaABAg
# 199  UgwJvMCt6dE5h1e53K14AaABAg
#
#                                  idComentarioPrincipal  \
# 0                           UgzBsMN6pxgQY2K5lz54AaABAg
# 1                           UgyVd0DyUTf_OiE9IK54AaABAg
# 2                           UgwurYvZu5q2W20drzB4AaABAg
# 3                           Ugx-lg8zr0L_XpyJmld4AaABAg
# 4                           Ugy83UUMZHG-LTErB3N4AaABAg
# ..                                                 ...
# 195  UgxtZYWotCV2o7JV3eR4AaABAg.9IrtcosXu2a9J07XwMBF7q
# 196  Ugxgw_CVAAlmMor6drB4AaABAg.9Ih7Ab9qXCd9JqsdPIAoJl
# 197  Ugwk1ZeFRVbZsvs9W-Z4AaABAg.9H70xWIhevO9Vy-AaDnP39
# ...

# %%
data=pd.concat([im,fp,ch,no])

# %%
data
# Out:
#                         idVideo  \
# 0                   fhb3Ms3Mj8s
# 1                   fhb3Ms3Mj8s
# 2                   fhb3Ms3Mj8s
# 3                   fhb3Ms3Mj8s
# 4                   41c8e5JrDwQ
# ..                          ...
# 195  UgxtZYWotCV2o7JV3eR4AaABAg
# 196  Ugxgw_CVAAlmMor6drB4AaABAg
# 197  Ugwk1ZeFRVbZsvs9W-Z4AaABAg
# 198  UgwJvMCt6dE5h1e53K14AaABAg
# 199  UgwJvMCt6dE5h1e53K14AaABAg
#
#                                  idComentarioPrincipal  \
# 0                           UgzhOuz_gV7AG6n-gqB4AaABAg
# 1                           UgyX63qpkYN0jA8a0OJ4AaABAg
# 2                           Ugw1V9tECDUchWT3unB4AaABAg
# 3                           UgzMPVkU8XFDbb8ciDV4AaABAg
# 4                           UgzRR0r0Q6DPP0nyct54AaABAg
# ..                                                 ...
# 195  UgxtZYWotCV2o7JV3eR4AaABAg.9IrtcosXu2a9J07XwMBF7q
# 196  Ugxgw_CVAAlmMor6drB4AaABAg.9Ih7Ab9qXCd9JqsdPIAoJl
# 197  Ugwk1ZeFRVbZsvs9W-Z4AaABAg.9H70xWIhevO9Vy-AaDnP39
# ...

# %%
data=data.dropna()

# %%
import sklearn

# %%
data_shuffled=sklearn.utils.shuffle(data)

# %%
data_shuffled
# Out:
#                         idVideo  \
# 118                 QI_RQxjivSY
# 5                   ADuMNEja1dQ
# 163  UgwsrddwrCrmTcMB_oN4AaABAg
# 182  UgyYKtc1ab1H87XBLGx4AaABAg
# 184  UgwhlaAjR8RmZzHAvsB4AaABAg
# ..                          ...
# 102  UgxCFfz0eucu3jBYtfZ4AaABAg
# 188  UgwZElE9QBa-FCqpOmh4AaABAg
# 29                  cYwqJ0AouSU
# 129                 EzZRBDvyWjg
# 30                  cYwqJ0AouSU
#
#                                  idComentarioPrincipal  \
# 118                         UgyZe2fkr29Fj11ZKOd4AaABAg
# 5                           Ugy-xr8HdUwOn22hN-x4AaABAg
# 163  UgwsrddwrCrmTcMB_oN4AaABAg.9PPH0_UmZoK9Pk9ZbrGdt3
# 182  UgyYKtc1ab1H87XBLGx4AaABAg.9MrE9Njy24r9Mx8Ncnajft
# 184  UgwhlaAjR8RmZzHAvsB4AaABAg.9M_nCo7-X1C9OeoqGF1-Ir
# ..                                                 ...
# 102  UgxCFfz0eucu3jBYtfZ4AaABAg.90IBV5EdpJt90P7vsR4Wpa
# 188  UgwZElE9QBa-FCqpOmh4AaABAg.9Lql-FGhba79T0UjRVTkhC
# 29                          UgwzurO8nTXKNKccA354AaABAg
# ...

# %%
path='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/EtiquetasYoutube/'

# %%
data_shuffled.to_excel(path+"DataYoutubeEtiquetados(FP,IM,CH,NO).xlsx")
