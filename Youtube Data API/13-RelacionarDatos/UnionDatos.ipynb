# %%
import pandas as pd
from google.colab import drive
import time
from datetime import datetime
from datetime import date
import os.path
from os import path
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Importamos datos en CSV (Para cada Serie)

# %% [markdown]
# ### Importamos Videos

# %%
# ======================== OJO Modificar para cada serie ========================

pathVD='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
Dignity/Videos/LematizadoRelevantesDignityRESULTS-VIDEOS2022-09-08 18_46_17.133286.xlsx'

# ======================== OJO Modificar para cada serie ========================

dfVD= pd.read_excel(pathVD)
dfVD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   idVideo                                      25 non-null     object
#  1   TituloVideo                                  25 non-null     object
#  2   TituloVideoModificado                        25 non-null     object
#  3   emojisTituloVideo                            25 non-null     object
#  4   URLsTituloVideo                              25 non-null     object
#  5   hashtagsTituloVideo                          25 non-null     object
#  6   MencionesTituloVideo                         25 non-null     object
#  7   DescripcionVideo                             24 non-null     object
#  8   DescripcionVideoModificado                   24 non-null     object
# ...

# %% [markdown]
# #### Eliminar columnas innecesarias (definidas por equipo gumelab)

# %%
dfVD=dfVD.drop(columns=['TituloVideoModificado','emojisTituloVideo','URLsTituloVideo','hashtagsTituloVideo','MencionesTituloVideo'\
                        ,'DescripcionVideoModificado','emojisDescripcionVideo','URLsDescripcionVideo','hashtagsDescripcionVideo','MencionesDescripcionVideo'\
                        ,'CategoriaVideo','FavoritoVideo','EtiquetasVideo','EtiquetasVideoTexto','TransmisionVivoVideo','idCanalVideo','TituloCanalVideo','ConsultaVideoModificado','SolicitudVideo'\
                        ,'TituloEtiquetasVideo','TotalTextoVideoModificado','Cos(BolsaPalabras)','Cos(TF_IDF)','Cos(Ngrams)','RelevanciaxPalabra','ConsultaVideoModificadoLematizadoProfundo','TotalTextoVideoModificadoLematizadoProfundo']) # RelevanciaxPalabra o Relevancia

# %%
dfVD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   idVideo                25 non-null     object
#  1   TituloVideo            25 non-null     object
#  2   DescripcionVideo       24 non-null     object
#  3   FechaPublicacionVideo  25 non-null     object
#  4   VistasVideo            25 non-null     int64
#  5   LikesVideo             24 non-null     float64
#  6   ComentariosVideo       23 non-null     float64
#  7   ConsultaVideo          25 non-null     object
#  8   PaisVideo              25 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.9+ KB

# %% [markdown]
# #### Añadimos columna Util y Comentario Gumelab (Solo si no hay comentarios Gumelab)

# %%
dfVD=dfVD.assign(UtilVideoSi_No="",ComentarioVideoGumelab="")

# %%
dfVD
# Out:
#         idVideo                                        TituloVideo  \
# 0   AConiNgYqZ4                             DIGNIDAD SERIE CHILENA
# 1   i_6E10appCA  👉🏻 Conoce la Historia de PAUL SCHÄFER 🤬 - 🏞️ D...
# 2   cYwqJ0AouSU    Dignidad - Tráiler oficial | Amazon Prime Video
# 3   IAUYxAH31rA               Dignidad' - Amazon Prime y Megamedia
# 4   W6uQKSkYSqs      MEGAMEDIA Y AMAZON PRIME PRESENTAN “DIGNIDAD”
# 5   K0N0U0gIaFk  Dignidad - Cosas que no sabías sobre Dignidad ...
# 6   BwNgtZIZWT4                 Dignidad - Serie - Tráiler ESPAÑOL
# 7   -x1vYTtm7MA  Crítica de "Dignidad", la nueva serie de Amazo...
# 8   O7B5ybluRIE  Dignidad, la serie de Amazon con un actor para...
# 9   icmkH5XYrDE  DIGNIDAD (2020) Tráiler HD [ESPAÑOL LATINO] Am...
# 10  9Z58zR-Me4g  DIGNIDAD (Teaser) - Próximamente por Amazon Pr...
# 11  NKpiPAX3iEg        Dignidad - Serie chilena Amazon Prime Video
# 12  Ry3M-kd_nB8  Dignidad (Amazon) Crítica | Reseña | Opinión |...
# ...

# %% [markdown]
# #### Importamos comentarios Gumelab Videos (Si los hay)

# %%
# ======================== OJO Modificar para cada serie ========================

pathVDCG='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Series/\
Narcos/DataAnalisis/RESULTS-VIDEOS(ComentariosGumelab)2022-05-19 18_04_23.516899.csv'

# ======================== OJO Modificar para cada serie ========================

dfVDCG= pd.read_csv(pathVDCG)
dfVDCG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2614 entries, 0 to 2613
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idVideo                 2614 non-null   object
#  1   Titulo                  2614 non-null   object
#  2   Descripcion             2379 non-null   object
#  3   FechaPublicacion        2614 non-null   object
#  4   Categoria               2614 non-null   int64
#  5   Vistas                  2614 non-null   int64
#  6   Likes                   2602 non-null   float64
#  7   Favorito                2614 non-null   int64
#  8   Comentarios             2543 non-null   float64
#  9   Etiquetas               2182 non-null   object
#  10  TransmisionVivo         2614 non-null   object
#  11  idRecursoCH             2614 non-null   object
#  12  TituloCanal             2614 non-null   object
#  13  Consulta                2614 non-null   object
# ...

# %%
dfVDCG=dfVDCG[['idVideo','UtilVideoSi_No','ComentarioVideoGumelab']]
dfVDCG
# Out:
#           idVideo UtilVideoSi_No  \
# 0     GJm7H9IP5SU             no
# 1     HCDtWCzJJYQ             no
# 2     DgYKWER9qv0             si
# 3     CPGcW2CtPfE             no
# 4     doku-BRZpD0             no
# ...           ...            ...
# 2609  UL9sQ8VNsxE            NaN
# 2610  gX9bIT4VP34            NaN
# 2611  any1ACFk7jg            NaN
# 2612  9gjSMUOmKV0            NaN
# 2613  0e0Q8LVtbXw            NaN
#
#                                  ComentarioVideoGumelab
# 0                                                   NaN
# 1                                                   NaN
# 2     el cartel de los sapos puede ser utilizado com...
# 3                    cancion de la serie (tabaco y ron)
# 4                                                   NaN
# ...                                                 ...
# 2609                                                NaN
# 2610                                                NaN
# ...

# %% [markdown]
# #### Uniendo Comentarios Gumelab a videos (Si los hay)

# %%
dfVD = pd.merge(left=dfVD, right=dfVDCG, how="left", left_on='idVideo', right_on='idVideo')
dfVD
# Out:
#          idVideo                                        TituloVideo  \
# 0    mVwiWbOLRRI                             Série Narcos - Netflix
# 1    zM_zMmuBSe4                           Série Boa Netflix Narcos
# 2    M3zk4NqFdn4   QUE VER Netflix Serie Narcos México 3 TEMPORADAS
# 3    NS8JbFvuTb4                                     NARCOS NETFLIX
# 4    gpxfidcKRZw                  Serie Netflix Narcos Colombianos.
# ..           ...                                                ...
# 872  WgJb-Jox6-A          El Barón | Capítulo 1 | Telemundo Novelas
# 873  TdRCIhYLVBs  Tenoch Huerta: ¿Las series de NARCOS están dañ...
# 874  DgYKWER9qv0                                    El Cartel Cap 1
# 875  aj0T7em123c                  Netflix  y El Patron / NTK CINEMA
# 876  Kw7NTEw1ilo  BLACKIE(sicario de confianza de pablo escobar)...
#
#                                       DescripcionVideo FechaPublicacionVideo  \
# ...

# %%
dfVD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 877 entries, 0 to 876
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idVideo                 877 non-null    object
#  1   TituloVideo             877 non-null    object
#  2   DescripcionVideo        817 non-null    object
#  3   FechaPublicacionVideo   877 non-null    object
#  4   VistasVideo             877 non-null    int64
#  5   LikesVideo              872 non-null    float64
#  6   ComentariosVideo        867 non-null    float64
#  7   ConsultaVideo           877 non-null    object
#  8   PaisVideo               877 non-null    object
#  9   UtilVideoSi_No          135 non-null    object
#  10  ComentarioVideoGumelab  25 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 82.2+ KB

# %% [markdown]
# #### Exportando base de datos reciente de videos completa (con comentarios Gumelab)

# %%
serie='Narcos'

# %%
ruta='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Series/\
'+serie+'/DataAnalisis'

# %%
dfVD.to_csv(ruta+'/'+'DataVideoTotal.csv', index=False)

# %% [markdown]
# ### Importamos Comentarios

# %%
# ======================== OJO Modificar para cada serie ========================

pathCM='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
Dignity/Comentarios/DataComentariosTotal(Dignity).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfCM= pd.read_excel(pathCM)
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1362 entries, 0 to 1361
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                1362 non-null   object
#  1   idComentarioPrincipal                  1362 non-null   object
#  2   TextoComentarioPrincipal               1360 non-null   object
#  3   FP/IM/CH/No (ComentarioPrincipal)      117 non-null    object
#  4   LikesComentarioPrincipal               1362 non-null   int64
#  5   ReplicasTotalesComentarioPrincipal     1362 non-null   int64
#  6   FechaPublicacionComentarioPrincipal    1362 non-null   object
#  7   FechaActualizacionComentarioPrincipal  1362 non-null   object
#  8   NombreAutorComentarioPrincipal         1362 non-null   object
#  9   PaisComentarioPrincipal                116 non-null    object
# ...

# %% [markdown]
# #### Eliminar columnas innecesarias (definidas por equipo gumelab)

# %%
dfCM=dfCM.drop(columns=['ComentarioPrincipalModificado','emojisComentarioPrincipal','URLsComentarioPrincipal','hashtagsComentarioPrincipal','MencionesComentarioPrincipal'\
                        ,'PublicoComentarioPrincipal','ReplicarComentarioPrincipal','URLAutorCanalComentarioPrincipal','idAutorCanalComentarioPrincipal','CalificacionEspectadorComentarioPrincipal'\
                        ,'CalificarComentarioPrincipal','SolicitudComentarioPrincipal'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ebc1dee61a4a> in <module>
# ----> 1 dfCM=dfCM.drop(columns=['ComentarioPrincipalModificado','emojisComentarioPrincipal','URLsComentarioPrincipal','hashtagsComentarioPrincipal','MencionesComentarioPrincipal'\
#       2                         ,'PublicoComentarioPrincipal','ReplicarComentarioPrincipal','URLAutorCanalComentarioPrincipal','idAutorCanalComentarioPrincipal','CalificacionEspectadorComentarioPrincipal'\
#       3                         ,'CalificarComentarioPrincipal','SolicitudComentarioPrincipal'])
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72493 entries, 0 to 72492
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                72493 non-null  object
#  1   idComentarioPrincipal                  72493 non-null  object
#  2   TextoComentarioPrincipal               72490 non-null  object
#  3   LikesComentarioPrincipal               72493 non-null  int64
#  4   ReplicasTotalesComentarioPrincipal     72493 non-null  int64
#  5   FechaPublicacionComentarioPrincipal    72493 non-null  object
#  6   FechaActualizacionComentarioPrincipal  72493 non-null  object
#  7   NombreAutorComentarioPrincipal         72491 non-null  object
#  8   PaisComentarioPrincipal                7022 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 5.0+ MB

# %% [markdown]
# #### Añadimos columna Util y Comentario Gumelab (Solo si no hay comentarios Gumelab)

# %%
dfCM=dfCM.assign(UtilComentarioPrincipalSi_No="",ComentarioPrincipal_ComentarioGumelab="")

# %%
dfCM
# Out:
#            idVideo       idComentarioPrincipal  \
# 0      NS8JbFvuTb4  UgzCxWFNA6dZNLaMVHF4AaABAg
# 1      NS8JbFvuTb4        UggpDwdh_GoZr3gCoAEC
# 2      NS8JbFvuTb4        UgjJ-eZxhsOPzXgCoAEC
# 3      NS8JbFvuTb4        UgiaTzlI9pYb0HgCoAEC
# 4      NS8JbFvuTb4        UgjADVVA9NaErXgCoAEC
# ...            ...                         ...
# 72488  Kw7NTEw1ilo  UgwRLwFItkt5bxP3CTV4AaABAg
# 72489  Kw7NTEw1ilo  UgwAqA0tzrT4YVPEX994AaABAg
# 72490  Kw7NTEw1ilo  UgycURaQpH7kRsBenLp4AaABAg
# 72491  Kw7NTEw1ilo  UgwRpQfsqW-9qoh27-h4AaABAg
# 72492  Kw7NTEw1ilo  UgzJGS6KOZpp__VCEt54AaABAg
#
#                                 TextoComentarioPrincipal  \
# 0                 la serie debería llamarse °parasitos°.
# 1      El Actor que encarna a Pablo Escobar tiene prá...
# 2                                                saludoz
# 3                                                saludoz
# 4                                                 saludo
# ...

# %% [markdown]
# #### Importamos comentarios Gumelab Comentarios (Si los hay)

# %%
# ======================== OJO Modificar para cada serie ========================

pathCMCG='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Series/\
Los80,MasqueUnaModa/Comentarios/RESULTS-PAISCOMENTARIOS(ComentariosGumelab)2022-05-23 19_12_49.773845.csv'

# ======================== OJO Modificar para cada serie ========================

dfCMCG= pd.read_csv(pathCMCG)
dfCMCG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34320 entries, 0 to 34319
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                34320 non-null  object
#  1   idComentarioPrincipal                  34320 non-null  object
#  2   TituloVideo                            34320 non-null  object
#  3   TextoOriginal                          34316 non-null  object
#  4   Likes                                  34320 non-null  float64
#  5   ReplicasTotales                        34320 non-null  float64
#  6   FechaPublicacion                       34320 non-null  object
#  7   FechaActualizacion                     34320 non-null  object
#  8   Publico                                34320 non-null  bool
#  9   Replicar                               34320 non-null  bool
# ...

# %%
dfCMCG=dfCMCG[['idComentarioPrincipal','UtilComentarioPrincipalSi_No','ComentarioPrincipal_ComentarioGumelab']]
dfCMCG
# Out:
#             idComentarioPrincipal UtilComentarioPrincipalSi_No  \
# 0      Ugyssrkl1-mq7niD-fl4AaABAg                           no
# 1      UgySO9FZJRCOiY2ZkVZ4AaABAg                           no
# 2            Ugho4ZiTBEvNungCoAEC                           no
# 3      UgwLvnmhkojeKCWEWFx4AaABAg                           no
# 4            UghGVZG4WJ608ngCoAEC                           no
# ...                           ...                          ...
# 34315  UgyrwmDj2MOGQtpIuWp4AaABAg                           no
# 34316  UgwlJJR6UkQTzBuDbLt4AaABAg                           no
# 34317  Ugy6gdbbpM4nbzYBZd54AaABAg                           no
# 34318  UgyzfRyvv6Uux9UveWB4AaABAg                           no
# 34319  UgwJl93t8DbwQFbZip94AaABAg                           no
#
#        ComentarioPrincipal_ComentarioGumelab
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# ...

# %% [markdown]
# #### Uniendo Comentarios Gumelab a comentarios (Si los hay)

# %%
dfCM = pd.merge(left=dfCM, right=dfCMCG, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
dfCM
# Out:
#           idVideo       idComentarioPrincipal  \
# 0     bSvTKiYCd6U  UgwL6MfUsP6dzFi71Bt4AaABAg
# 1     bSvTKiYCd6U  Ugx6n7d9wC7mrUgruvd4AaABAg
# 2     bSvTKiYCd6U  UgxC7jOe4iaaFO6Xndd4AaABAg
# 3     bSvTKiYCd6U  UgyjHCxr_2kbwgddVAt4AaABAg
# 4     bSvTKiYCd6U  Ugw2-Pc641nlZ2Y-u-B4AaABAg
# ...           ...                         ...
# 9339  -FBSV-tMTWo  Ugy7Xt2tQbhv_NiPYVN4AaABAg
# 9340  iF1dfqpkuUM        UghEYABpIYDl7XgCoAEC
# 9341  iF1dfqpkuUM  UgyeJ-jFj5n8k5DbfUd4AaABAg
# 9342  phIsk2tqBUk  Ugzntd7xfFnTOqe7cDR4AaABAg
# 9343  BatgRD9sNkI  Ugws0R8_u2NYv4InIVR4AaABAg
#
#                                TextoComentarioPrincipal  \
# 0          Quien es el creador de esta hermosa melodia?
# 1                                                   :')
# 2                                             Muy buena
# 3     Lo mejorrrrrrrrr de lo mejorrrrrrr🇨🇱🇨🇱🇨🇱🇨🇱🇨🇱🇨🇱...
# 4     Y hoy  despues  de 39 años  viviendo  algo bas...
# ...                                                 ...
# ...

# %%
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9344 entries, 0 to 9343
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                9344 non-null   object
#  1   idComentarioPrincipal                  9344 non-null   object
#  2   TextoComentarioPrincipal               9343 non-null   object
#  3   LikesComentarioPrincipal               9344 non-null   int64
#  4   ReplicasTotalesComentarioPrincipal     9344 non-null   int64
#  5   FechaPublicacionComentarioPrincipal    9344 non-null   object
#  6   FechaActualizacionComentarioPrincipal  9344 non-null   object
#  7   NombreAutorComentarioPrincipal         9344 non-null   object
#  8   PaisComentarioPrincipal                573 non-null    object
#  9   UtilComentarioPrincipalSi_No           6197 non-null   object
# ...

# %% [markdown]
# #### Exportando base de datos reciente de comentarios completa (con comentarios Gumelab)

# %%
serie='Los80,MasqueUnaModa'

# %%
ruta='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Series/\
'+serie+'/Comentarios'

# %%
dfCM.to_csv(ruta+'/'+'DataComentariosTotal.csv', index=False)

# %% [markdown]
# ### Importamos Respuestas a Comentarios

# %%
# ======================== OJO Modificar para cada serie ========================

pathRCM='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
Dignity/RespuestasComentarios/RESULTS-PAISCOMENTARIOS-Lematizado2022-09-08 19_08_59.751723(Dignity).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfRCM= pd.read_excel(pathRCM)
dfRCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787 entries, 0 to 786
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idComentarioPrincipal                            787 non-null    object
#  1   idComentarioRespuesta                            787 non-null    object
#  2   TextoComentarioRespuesta                         786 non-null    object
#  3   FP/IM/CH/No (ComentarioRespuesta)                185 non-null    object
#  4   ComentarioRespuestaModificado                    787 non-null    object
#  5   emojisComentarioRespuesta                        787 non-null    object
#  6   URLsComentarioRespuesta                          787 non-null    object
#  7   hashtagsComentarioRespuesta                      787 non-null    object
#  8   MencionesComentarioRespuesta                     787 non-null    object
# ...

# %% [markdown]
# #### Eliminar columnas innecesarias (definidas por equipo gumelab)

# %%
dfRCM=dfRCM.drop(columns=['ComentarioRespuestaModificado','emojisComentarioRespuesta','URLsComentarioRespuesta','hashtagsComentarioRespuesta','MencionesComentarioRespuesta'\
                          ,'URLAutorCanalComentarioRespuesta','idAutorCanalComentarioRespuesta','CalificacionEspectadorComentarioRespuesta','CalificarComentarioRespuesta','SolicitudComentarioRespuesta'])

# %%
dfRCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787 entries, 0 to 786
# Data columns (total 10 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idComentarioPrincipal                            787 non-null    object
#  1   idComentarioRespuesta                            787 non-null    object
#  2   TextoComentarioRespuesta                         786 non-null    object
#  3   FP/IM/CH/No (ComentarioRespuesta)                185 non-null    object
#  4   LikesComentarioRespuesta                         787 non-null    float64
#  5   FechaPublicacionComentarioRespuesta              787 non-null    object
#  6   FechaActualizacionComentarioRespuesta            787 non-null    object
#  7   NombreAutorComentarioRespuesta                   787 non-null    object
#  8   PaisComentarioRespuesta                          58 non-null     object
# ...

# %% [markdown]
# #### Añadimos columna Util y Comentario Gumelab (Solo si no hay comentarios Gumelab)

# %%
dfRCM=dfRCM.assign(UtilComentarioRespuestaSi_No="",ComentarioRespuesta_ComentarioGumelab="")

# %%
dfRCM
# Out:
#           idComentarioPrincipal  \
# 0    Ugx-lg8zr0L_XpyJmld4AaABAg
# 1    Ugw2_kxb9a7f_bB4YWd4AaABAg
# 2    Ugw2_kxb9a7f_bB4YWd4AaABAg
# 3    Ugx3q99ebSKo8ST0AjV4AaABAg
# 4    UgzSfdFLv5i5PzKcPVd4AaABAg
# ..                          ...
# 782  UgwJbqTXK8VyO9xNYhd4AaABAg
# 783  UgwJbqTXK8VyO9xNYhd4AaABAg
# 784  UgwJbqTXK8VyO9xNYhd4AaABAg
# 785  UgxzlFe5QmLGH_vyGKh4AaABAg
# 786  UgxzlFe5QmLGH_vyGKh4AaABAg
#
#                                  idComentarioRespuesta  \
# 0    Ugx-lg8zr0L_XpyJmld4AaABAg.9GAwh9-f18D9GB6nnFdhpB
# 1    Ugw2_kxb9a7f_bB4YWd4AaABAg.9IlPL4G3_BT9SzfqkduJlA
# 2    Ugw2_kxb9a7f_bB4YWd4AaABAg.9IlPL4G3_BT9JTWT87_2au
# 3    Ugx3q99ebSKo8ST0AjV4AaABAg.9GcPacMg_oE9GckMGY8I1N
# 4    UgzSfdFLv5i5PzKcPVd4AaABAg.9GVUxCAYxPY9Vjd7nNthoh
# ..                                                 ...
# 782  UgwJbqTXK8VyO9xNYhd4AaABAg.9GEzb-6ZJyT9GHo1UUOci7
# 783  UgwJbqTXK8VyO9xNYhd4AaABAg.9GEzb-6ZJyT9GHo-CsS81H
# 784  UgwJbqTXK8VyO9xNYhd4AaABAg.9GEzb-6ZJyT9GFOWtI9TtJ
# ...

# %% [markdown]
# #### Importamos comentarios Gumelab Respuestas Comentarios (Si los hay)

# %%
# ======================== OJO Modificar para cada serie ========================

pathRCCG='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/PaisesCanales/Comentarios/\
Dignity/2022-05-20/RESULTS-PAISCOMENTARIOS(Gumelab)2022-05-20 14_19_51.134013.csv'

# ======================== OJO Modificar para cada serie ========================

dfRCCG= pd.read_csv(pathRCCG)
dfRCCG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                1110 non-null   object
#  1   idComentarioPrincipal                  1110 non-null   object
#  2   TituloVideo                            1110 non-null   object
#  3   TextoOriginal                          1110 non-null   object
#  4   Likes                                  1110 non-null   int64
#  5   ReplicasTotales                        1110 non-null   int64
#  6   FechaPublicacion                       1110 non-null   object
#  7   FechaActualizacion                     1110 non-null   object
#  8   Publico                                1110 non-null   bool
#  9   Replicar                               1110 non-null   bool
# ...

# %%
dfRCCG=dfRCCG[['idComentarioRespuesta','UtilComentarioRespuestaSi_No','ComentarioRespuesta_ComentarioGumelab']]
dfRCCG
# Out:
#            idComentarioPrincipal UtilComentarioPrincipalSi_No  \
# 0     UgzptWDhwsVRwYQEP8p4AaABAg                           no
# 1     UgxtDUYeVuDx5LalexR4AaABAg                           si
# 2     UgyZZNknVrhIQqlcP4d4AaABAg                           no
# 3     UgxiDzR6yUNDwmMlfMt4AaABAg                           no
# 4     UgwDAOuz6EWwa2q4Xq54AaABAg                           no
# ...                          ...                          ...
# 1105  UgwTViJKH2nAi2kCwfZ4AaABAg                          NaN
# 1106  Ugy9F8tayryxBRoWQj54AaABAg                          NaN
# 1107  Ugy3m5-TnUlnChiPSBN4AaABAg                          NaN
# 1108  Ugz-XbFFios7TUsDNGV4AaABAg                          NaN
# 1109  Ugy4c1xjJ4aoDAcdZfF4AaABAg                          NaN
#
#       ComentarioPrincipal_ComentarioGumelab
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# ...

# %% [markdown]
# #### Uniendo Respuestas Comentarios Gumelab (Si los hay)

# %%
dfRCM = pd.merge(left=dfRCM, right=dfRCCG, how="left", left_on='idComentarioRespuesta', right_on='idComentarioRespuesta')
dfRCM
# Out:
#           idVideo       idComentarioPrincipal  \
# 0     -x1vYTtm7MA  UgwoMmmVztB6NYxlxJh4AaABAg
# 1     -x1vYTtm7MA  UgxLAJ9b5-fi69UR7pB4AaABAg
# 2     -x1vYTtm7MA  Ugx0e66UvwlmyeE7cI94AaABAg
# 3     -x1vYTtm7MA  UgxfZhLLEnzVGDsOqI54AaABAg
# 4     -x1vYTtm7MA  Ugwf7kGC0I6T2cx5xGt4AaABAg
# ...           ...                         ...
# 1358  oNVVAkYNcro  UgwyQEBnFal9LZ8rEuh4AaABAg
# 1359  oNVVAkYNcro  UgzbmVJjQNkWHgf_3Jh4AaABAg
# 1360  oNVVAkYNcro  UgzQHUZD_VjdHhG_YOR4AaABAg
# 1361  oNVVAkYNcro  Ugwh7rdxcjC3vLSY1VV4AaABAg
# 1362  oNVVAkYNcro  Ugx51WGLx6yoinkAEVt4AaABAg
#
#                                TextoComentarioPrincipal  \
# 0                               Un seco Felipe Tapia!!!
# 1                                   Excelente análisis.
# 2     Estuvo buena la serie y si se ve como algo que...
# 3     Excelente crítica y genial video: siempre se d...
# 4     Cuando te refieres a la trama de "La jauría" c...
# ...                                                 ...
# ...

# %%
dfRCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1363 entries, 0 to 1362
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                1363 non-null   object
#  1   idComentarioPrincipal                  1363 non-null   object
#  2   TextoComentarioPrincipal               1361 non-null   object
#  3   LikesComentarioPrincipal               1363 non-null   int64
#  4   ReplicasTotalesComentarioPrincipal     1363 non-null   int64
#  5   FechaPublicacionComentarioPrincipal    1363 non-null   object
#  6   FechaActualizacionComentarioPrincipal  1363 non-null   object
#  7   NombreAutorComentarioPrincipal         1362 non-null   object
#  8   PaisComentarioPrincipal                116 non-null    object
#  9   UtilComentarioPrincipalSi_No           87 non-null     object
# ...

# %% [markdown]
# ## Uniendo Comentarios a Videos

# %%
resultVC = pd.merge(left=dfVD, right=dfCM, how="left", left_on='idVideo', right_on='idVideo')
resultVC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1377 entries, 0 to 1376
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idVideo                                1377 non-null   object
#  1   TituloVideo                            1377 non-null   object
#  2   DescripcionVideo                       1376 non-null   object
#  3   FechaPublicacionVideo                  1377 non-null   object
#  4   VistasVideo                            1377 non-null   int64
#  5   LikesVideo                             1376 non-null   float64
#  6   ComentariosVideo                       1375 non-null   float64
#  7   ConsultaVideo                          1377 non-null   object
#  8   PaisVideo                              1377 non-null   object
#  9   UtilVideoSi_No                         1377 non-null   object
# ...

# %% [markdown]
# ## Uniendo Respuestas a Comentarios

# %%
resultRVC = pd.merge(left=resultVC, right=dfRCM, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
resultRVC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1961 entries, 0 to 1960
# Data columns (total 33 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idVideo                                          1961 non-null   object
#  1   TituloVideo                                      1961 non-null   object
#  2   DescripcionVideo                                 1960 non-null   object
#  3   FechaPublicacionVideo                            1961 non-null   object
#  4   VistasVideo                                      1961 non-null   int64
#  5   LikesVideo                                       1960 non-null   float64
#  6   ComentariosVideo                                 1959 non-null   float64
#  7   ConsultaVideo                                    1961 non-null   object
#  8   PaisVideo                                        1961 non-null   object
# ...

# %% [markdown]
# ## Exportando a CSV (Para cada Serie)

# %%
today = str(date.today())

# ===== OJO Cambiar para cada Serie =====

PATH_TO_SAVE_SEARCHES = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Series/Narcos/DataGumelab/'

# ===== OJO Cambiar para cada Serie =====

PATH_TO_DIR_0 = PATH_TO_SAVE_SEARCHES + today
if os.path.exists(PATH_TO_DIR_0) == False:
  os.mkdir(PATH_TO_DIR_0)
file_nameL = 'DATOSSSUPREMO'+str(datetime.now())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5a79a64d9db5> in <module>
# ----> 1 today = str(date.today())
#       2
#       3 # ===== OJO Cambiar para cada Serie =====
#       4
#       5 PATH_TO_SAVE_SEARCHES = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Series/Narcos/DataGumelab/'
#
# NameError: name 'date' is not defined

# %%
resultRVC.to_excel(PATH_TO_DIR_0+'/'+'RESULTS-'+file_nameL+'.xlsx', index=False)

# %%
resultRVC
# Out:
#             idVideo                                        TituloVideo  \
# 0       mVwiWbOLRRI                             Série Narcos - Netflix
# 1       zM_zMmuBSe4                           Série Boa Netflix Narcos
# 2       M3zk4NqFdn4   QUE VER Netflix Serie Narcos México 3 TEMPORADAS
# 3       NS8JbFvuTb4                                     NARCOS NETFLIX
# 4       NS8JbFvuTb4                                     NARCOS NETFLIX
# ...             ...                                                ...
# 106746  Kw7NTEw1ilo  BLACKIE(sicario de confianza de pablo escobar)...
# 106747  Kw7NTEw1ilo  BLACKIE(sicario de confianza de pablo escobar)...
# 106748  Kw7NTEw1ilo  BLACKIE(sicario de confianza de pablo escobar)...
# 106749  Kw7NTEw1ilo  BLACKIE(sicario de confianza de pablo escobar)...
# 106750  Kw7NTEw1ilo  BLACKIE(sicario de confianza de pablo escobar)...
#
#                                          DescripcionVideo  \
# ...
