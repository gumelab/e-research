# %% [markdown]
# # Youtube Data API: Search Canales
# https://developers.google.com/youtube/v3/docs/search

# %% [markdown]
# ## Contenido:
#
# * [Librerias](*Librerias)
# * [Search](*Search)

# %% [markdown]
# <a name="Librerias"></a>
# ## Librerias

# %%
# ========= Data Cleaning =========

# !pip install advertools
# !pip install clean-text
# !pip install urlextract
import advertools as adv
from urlextract import URLExtract
from nltk.tokenize import regexp_tokenize
import html
import string 
import re
from cleantext import clean
import unicodedata

# ========= Data Cleaning =========

import pandas as pd
import requests
import csv
import time
from datetime import datetime
from datetime import date
import os.path
from os import path
from google.colab import drive
key='AIzaSyBiLyWsQjmoRY63q8F_Jcp0zFM5eWXkFx8'
drive.mount('/content/drive/')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 309 kB 28.9 MB/s
# ...
#      |████████████████████████████████| 264 kB 54.8 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 35.1 MB/s
# ...
#      |████████████████████████████████| 55 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 251 kB 52.4 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 36.4 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.4 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11958 sha256=a743cccd7e82d0c868059efb54410288e532b210b856c7865f87eff3ecb78428
#   Stored in directory: /root/.cache/pip/wheels/c9/d6/6a/de198d890277cde60ca3dbebe7ae592d3b381c7d9bb2455f4d
# Successfully built PyDispatcher
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #### https://www.youtube.com/playlist?list=
# #### https://www.youtube.com/channel/
# #### https://www.youtube.com/watch?v=

# %% [markdown]
# ## Search Canales

# %% [markdown]
# ### Ejecucion

# %% [markdown]
# #### Parametros constantes

# %%
URIs = 'https://www.googleapis.com/youtube/v3/search?key='

# ================== Parametros Requeridos ==================

part = 'snippet' # Parametro obligatorio

# ================== Parametros opcionales ==================

maxResults = '50' # Numero maximo de elementos a devolver. El rango es 0 a 50.
order = 'viewCount' # Metodo para ordenar los resultados. date = orden cronologico inverso, ====> OJO Revisar
# rating = se ordenan de mayor a menor calificacion, relevance = se ordenan segun su relevancia (predeterminado),
# title = alfabeticamente por titulo, videCount = orden descendente de su numero de videos subidos, 
# viewCount = de mayor a menor numero de vistas.

relevanceLanguage = 'es' # Devuelve resultados de busqueda mas relevantes para el idioma especificado (Codigo 2 letras)
tipo = 'video' # Recupera un tipo partcilar de recurso video, channel o playlist el valor predeterminado es video,channel,playlist

# %% [markdown]
# #### Parametros variables

# %%
# ================== Parametros opcionales ==================

channelId = 'UCvK5stjF8Oq9VCwC78DWVew' # Indicar que la respuesta solo debe tener resultados de este canal
pageToken = '' # Pagina especifica que se debe devolver

# %% [markdown]
# #### Solicitud

# %%
r = requests.get(URIs+key+'&part='+part+'&channelId='+channelId\
                 +'&maxResults='+maxResults+'&pageToken='+pageToken\
                 +'&order='+order+'&relevanceLanguage='+relevanceLanguage\
                 +'&type='+tipo)

# %%
r
# Out:
# <Response [200]>

# %%
r.reason
# Out:
# 'OK'

# %%
d = dict(r.json())

# %%
d.keys()
# Out:
# dict_keys(['kind', 'etag', 'regionCode', 'pageInfo', 'items'])

# %%
d
# Out:
# {'etag': 'r4eipQ38b5XJTc6dmwJUq2o1B90',
#  'items': [{'etag': 'pwATvSUIKelPXzKLKnn58zpN9YQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'FFL8OWZJB3E'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCvK5stjF8Oq9VCwC78DWVew',
#     'channelTitle': 'PABLO ESCOBAR CAPITULOS',
#     'description': 'SUSCRIBETE A ESTE CANAL PARA QUE LE LLEGUEN LOS VIDEO K SUBAS Y ACTIVA LA CANPANITA.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-03-08T17:15:53Z',
#     'publishedAt': '2019-03-08T17:15:53Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/FFL8OWZJB3E/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/FFL8OWZJB3E/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/FFL8OWZJB3E/mqdefault.jpg',
#       'width': 320}},
#     'title': 'PABLO ESCOBAR CAPITULO 4 COMPLETO'}},
# ...

# %%
d['kind']
# Out:
# 'youtube#searchListResponse'

# %%
d['etag']
# Out:
# 'r4eipQ38b5XJTc6dmwJUq2o1B90'

# %%
d['regionCode']
# Out:
# 'US'

# %%
d['pageInfo']
# Out:
# {'resultsPerPage': 6, 'totalResults': 6}

# %%
d['nextPageToken']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-ce19cc3d424c> in <module>()
# ----> 1 d['nextPageToken']
#
# KeyError: 'nextPageToken'

# %% [markdown]
# #### Resultados

# %%
items = d.get('items')
items
# Out:
# [{'etag': 'pwATvSUIKelPXzKLKnn58zpN9YQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'FFL8OWZJB3E'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCvK5stjF8Oq9VCwC78DWVew',
#    'channelTitle': 'PABLO ESCOBAR CAPITULOS',
#    'description': 'SUSCRIBETE A ESTE CANAL PARA QUE LE LLEGUEN LOS VIDEO K SUBAS Y ACTIVA LA CANPANITA.',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-03-08T17:15:53Z',
#    'publishedAt': '2019-03-08T17:15:53Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/FFL8OWZJB3E/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/FFL8OWZJB3E/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/FFL8OWZJB3E/mqdefault.jpg',
#      'width': 320}},
#    'title': 'PABLO ESCOBAR CAPITULO 4 COMPLETO'}},
#  {'etag': '-k5ignPXr8fX1HWI34i5o1NZsgk',
# ...

# %% [markdown]
# #### Dataframe

# %%
data=pd.json_normalize(items)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   kind                               6 non-null      object
#  1   etag                               6 non-null      object
#  2   id.kind                            6 non-null      object
#  3   id.videoId                         6 non-null      object
#  4   snippet.publishedAt                6 non-null      object
#  5   snippet.channelId                  6 non-null      object
#  6   snippet.title                      6 non-null      object
#  7   snippet.description                6 non-null      object
#  8   snippet.thumbnails.default.url     6 non-null      object
#  9   snippet.thumbnails.default.width   6 non-null      int64
#  10  snippet.thumbnails.default.height  6 non-null      int64
# ...

# %%
data
# Out:
#                    kind                         etag        id.kind  \
# 0  youtube#searchResult  pwATvSUIKelPXzKLKnn58zpN9YQ  youtube#video
# 1  youtube#searchResult  -k5ignPXr8fX1HWI34i5o1NZsgk  youtube#video
# 2  youtube#searchResult  bSAL0XiLD3PROAQWkTUlf7BMhOE  youtube#video
# 3  youtube#searchResult  2cvwETIKEIZqdI7PvGLaCoQE7kQ  youtube#video
# 4  youtube#searchResult  OgYWqdvO9HX_ekD6pHrFkj1PXE0  youtube#video
# 5  youtube#searchResult  P0nEGA3bpcp-hORFl6-DaNODTwI  youtube#video
#
#     id.videoId   snippet.publishedAt         snippet.channelId  \
# 0  FFL8OWZJB3E  2019-03-08T17:15:53Z  UCvK5stjF8Oq9VCwC78DWVew
# 1  FoIFYsDpt6s  2019-03-06T00:50:45Z  UCvK5stjF8Oq9VCwC78DWVew
# 2  E-wWAoKWHQY  2019-03-05T17:03:38Z  UCvK5stjF8Oq9VCwC78DWVew
# 3  Q8WvYD6LJqE  2019-03-26T22:25:15Z  UCvK5stjF8Oq9VCwC78DWVew
# 4  dYXEoTMRAPc  2019-03-13T05:49:51Z  UCvK5stjF8Oq9VCwC78DWVew
# 5  jI1EOXsQ3UU  2019-03-26T22:23:02Z  UCvK5stjF8Oq9VCwC78DWVew
#
# ...

# %% [markdown]
# ### Algoritmo en produccion

# %% [markdown]
# #### Importando Datos

# %%
# ======================= OJO Cambiar PATH para cada Serie =======================

path='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/Search/\
Narcos/2022-09-13SV(2022-09-12)CR(2022-09-13)/Canales.csv' 

# ======================= OJO Cambiar PATH para cada Serie =======================

canales=pd.read_csv(path)
canales
# Out:
#            Recurso               idRecursoCH  \
# 0  youtube#channel  UCeS-Pf1x2QH4zdvAvPeirBg
# 1  youtube#channel  UCwbawoPb2unO3xzjppgb3oA
# 2  youtube#channel  UC2_duYcx0PrmmdCTPXdUyfg
# 3  youtube#channel  UC1Wp0GeyY9enciSnVQtC5Yg
#
#                                               Titulo  \
# 0  Narcos, Vol. 2 (More Music from the Netflix Or...
# 1  Tuyo (Narcos Theme) [Extended Version] (A Netf...
# 2          Narcos Main Theme - Tuyo (Netflix Series)
# 3                                     Narcos [Serie]
#
#                                     TituloModificado emojisTitulo URLsTitulo  \
# 0  narcos vol more music from the netflix origina...           []         []
# 1  tuyo narcos theme extended version netflix ori...           []         []
# 2              narcos main theme tuyo netflix series           []         []
# 3                                       narcos serie           []         []
#
#   hastagsTitulo MencionesTitulo  \
# 0            []              []
# ...

# %%
dataCH=canales.loc[:,['idRecursoCH','Consulta','Pais']]
dataCH
# Out:
#                 idRecursoCH                              Consulta Pais
# 0  UCeS-Pf1x2QH4zdvAvPeirBg  serie Narcos netflix -mexico -cielos   CO
# 1  UCwbawoPb2unO3xzjppgb3oA        serie "Narcos" Netflix -mexico   CO
# 2  UC2_duYcx0PrmmdCTPXdUyfg        serie "Narcos" Netflix -mexico   CO
# 3  UC1Wp0GeyY9enciSnVQtC5Yg        serie "Narcos" Netflix -mexico   CO

# %% [markdown]
# #### Construimos lista de ids

# %%
ListIds=list(dataCH['idRecursoCH'])
ListIds
# Out:
# ['UCeS-Pf1x2QH4zdvAvPeirBg',
#  'UCwbawoPb2unO3xzjppgb3oA',
#  'UC2_duYcx0PrmmdCTPXdUyfg',
#  'UC1Wp0GeyY9enciSnVQtC5Yg']

# %% [markdown]
# #### Parametros constantes

# %%
URIs = 'https://www.googleapis.com/youtube/v3/search?key='

# ================== Parametros Requeridos ==================

part = 'snippet' # Parametro obligatorio
fields = 'pageInfo(*),nextPageToken(*),prevPageToken(*)\
,items(id(videoId),snippet(title,description,publishedAt,liveBroadcastContent,channelId,channelTitle))'

# ================== Parametros opcionales ==================

maxResults = '50' # Numero maximo de elementos a devolver. El rango es 0 a 50.
order = 'viewCount' # Metodo para ordenar los resultados. date = orden cronologico inverso, ====> OJO Revisar
# rating = se ordenan de mayor a menor calificacion, relevance = se ordenan segun su relevancia (predeterminado),
# title = alfabeticamente por titulo, videCount = orden descendente de su numero de videos subidos, 
# viewCount = de mayor a menor numero de vistas.

relevanceLanguage = 'es' # Devuelve resultados de busqueda mas relevantes para el idioma especificado (Codigo 2 letras)
tipo = 'video' # Recupera un tipo partcilar de recurso video, channel o playlist el valor predeterminado es video,channel,playlist

# %% [markdown]
# #### Parametros variables

# %%
# ================== Parametros opcionales ==================

channelId = ListIds # Indicar que la respuesta solo debe tener resultados de este canal
pageToken = '' # Pagina especifica que se debe devolver

# %% [markdown]
# #### Carpetas Drive

# %%
today = str(date.today())

# ======================= OJO Cambiar PATH para cada Serie =======================

PATH_TO_SAVE_SEARCHES = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/YoutubeResults/SearchCanales/Narcos/'

# ======================= OJO Cambiar PATH para cada Serie =======================

PATH_TO_DIR_0 = PATH_TO_SAVE_SEARCHES + today
if os.path.exists(PATH_TO_DIR_0) == False:
  os.mkdir(PATH_TO_DIR_0)
file_nameL = 'SEARCHCANALES'+str(datetime.now())

# %% [markdown]
# #### Constantes

# %%
solicitud = 0 # Inicio de las solicitudes
paginasmax = 100 # Numero de paginas maximas
solicitudmax = 50 # Solicitudes maximas, el limite es 100
espera = 0.5 # Valor de retardo para las solicitudes

# ======================= OJO Cambiar diariamente =======================

ithId = 0 # i-esimo id

# ======================= OJO Cambiar diariamente =======================

# %% [markdown]
# #### Ejecucion

# %%
Datac = pd.DataFrame() # Dataframe de Resultados Totales
Metadatac = pd.DataFrame(columns=['Solicitud','IdRecursoCH','maxResultados','FechaEjecucion','Respuesta'\
                                  ,'prevPageToken','nextPageToken','ResultadosTotal','Resultadosxpagina']) # Dataframe de Informacion de Solicitudes

for id in channelId[ithId:]: # For de lista de ids de canales
  
  if (solicitud == solicitudmax+1):
    break
  
  pageToken = '' # Pagina especifica que se debe devolver OJO DEBE DE IR EN ESTE LUGAR
  
  for pagina in range(1,paginasmax+1): # For de la paginacion

    solicitud = solicitud+1

    if (solicitud == solicitudmax+1):
      ptoPartida = [] # Punto de partida para volver a comenzar el motor de busqueda en produccion.
      break

    time.sleep(espera) # Tiempo de espera por cada solicitud
    r = requests.get(URIs+key+'&part='+part+'&fields='+fields+'&channelId='+id+'&maxResults='+maxResults\
                     +'&pageToken='+pageToken+'&order='+order\
                     +'&relevanceLanguage='+relevanceLanguage+'&type='+tipo) # Solicitud
    
    print('solicitud',solicitud,r.reason)

    if (r.reason == 'OK'): # Vemos si la solicitud fue exitosa

      d = dict(r.json())
      claves = list(d.keys())
      items = d.get('items')
      Data = pd.json_normalize(items).assign(Solicitud = solicitud)
      Datac = pd.concat([Datac, Data], ignore_index = True)

      if ('nextPageToken' in claves): # Si hay siguiente pagina
        pageToken = d['nextPageToken'] # Definimos el proximo pagetoken
        if ('prevPageToken' in claves):
          prevPageToken = d['prevPageToken']
        else:
          prevPageToken = ''

        Metadatac = Metadatac.append({'Solicitud':solicitud,'IdRecursoCH':id,'maxResultados':maxResults,'FechaEjecucion':str(datetime.now())\
                                      ,'Respuesta':r.reason,'nextPageToken':d['nextPageToken'],'prevPageToken':prevPageToken\
                                      ,'ResultadosTotal':d['pageInfo']['totalResults'],'Resultadosxpagina':d['pageInfo']['resultsPerPage']}, ignore_index = True)
        print('Siguiente pagina')

      else: # Si no hay siguiente pagina
        nextPageToken = '' # Definimos el nextPageToken como vacio
        if ('prevPageToken' in claves): 
          prevPageToken=d['prevPageToken']
        else:
          prevPageToken=''

        Metadatac = Metadatac.append({'Solicitud':solicitud,'IdRecursoCH':id,'maxResultados':maxResults,'FechaEjecucion':str(datetime.now())\
                                      ,'Respuesta':r.reason,'nextPageToken':nextPageToken,'prevPageToken':prevPageToken\
                                      ,'ResultadosTotal':d['pageInfo']['totalResults'],'Resultadosxpagina':d['pageInfo']['resultsPerPage']}, ignore_index=True)
        print("No hay mas paginas")
        break
    else: # Vemos si la solicitud no fue exitosa    
      print("No fue exitosa la solicitud", solicitud) 
print("Busqueda Terminada")
# Out:
# solicitud 1 OK
# No hay mas paginas
# solicitud 2 OK
# No hay mas paginas
# solicitud 3 OK
# No hay mas paginas
# solicitud 4 OK
# No hay mas paginas
# Busqueda Terminada

# %%
Datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Solicitud  0 non-null      int64
# dtypes: int64(1)
# memory usage: 124.0 bytes

# %%
Datac
# Out:
# Empty DataFrame
# Columns: [Solicitud]
# Index: []

# %%
Metadatac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Solicitud          4 non-null      object
#  1   IdRecursoCH        4 non-null      object
#  2   maxResultados      4 non-null      object
#  3   FechaEjecucion     4 non-null      object
#  4   Respuesta          4 non-null      object
#  5   prevPageToken      4 non-null      object
#  6   nextPageToken      4 non-null      object
#  7   ResultadosTotal    4 non-null      object
#  8   Resultadosxpagina  4 non-null      object
# dtypes: object(9)
# memory usage: 416.0+ bytes

# %%
Metadatac
# Out:
#   Solicitud               IdRecursoCH maxResultados  \
# 0         1  UCeS-Pf1x2QH4zdvAvPeirBg            50
# 1         2  UCwbawoPb2unO3xzjppgb3oA            50
# 2         3  UC2_duYcx0PrmmdCTPXdUyfg            50
# 3         4  UC1Wp0GeyY9enciSnVQtC5Yg            50
#
#                FechaEjecucion Respuesta prevPageToken nextPageToken  \
# 0  2022-09-13 13:57:46.826362        OK
# 1  2022-09-13 13:57:47.563778        OK
# 2  2022-09-13 13:57:48.297646        OK
# 3  2022-09-13 13:57:49.023597        OK
#
#   ResultadosTotal Resultadosxpagina
# 0               0                 0
# 1               0                 0
# 2               0                 0
# 3               1                 0

# %% [markdown]
# #### Estructurar y dar formato a Dataframe

# %%
columnas={'id.videoId':'idRecursoVD','snippet.title':'Titulo','snippet.description':'Descripcion'\
          ,'snippet.publishedAt':'TiempoPublicacion','snippet.liveBroadcastContent':'TransmisionVivo','snippet.channelId':'idCanal'\
          ,'snippet.channelTitle':'TituloCanal','Solicitud':'Solicitud'}

columnasorden=['idRecursoVD','Titulo','Descripcion','TiempoPublicacion','TransmisionVivo'\
               ,'idCanal','TituloCanal','Solicitud']

Datac.rename(columns=columnas,inplace=True)
DATA=Datac.reindex(columns=columnasorden)
DATA
# Out:
# Empty DataFrame
# Columns: [idRecursoVD, Titulo, Descripcion, TiempoPublicacion, TransmisionVivo, idCanal, TituloCanal, Solicitud]
# Index: []

# %% [markdown]
# #### Uniendo columnas de importancia

# %%
mergedinner = pd.merge(left=DATA,right=dataCH, left_on='idCanal', right_on='idRecursoCH').drop(['idRecursoCH'], axis=1)
mergedinner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idRecursoVD        0 non-null      float64
#  1   Titulo             0 non-null      float64
#  2   Descripcion        0 non-null      float64
#  3   TiempoPublicacion  0 non-null      float64
#  4   TransmisionVivo    0 non-null      float64
#  5   idCanal            0 non-null      float64
#  6   TituloCanal        0 non-null      float64
#  7   Solicitud          0 non-null      int64
#  8   Consulta           0 non-null      object
#  9   Pais               0 non-null      object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
mergedinner
# Out:
# Empty DataFrame
# Columns: [idRecursoVD, Titulo, Descripcion, TiempoPublicacion, TransmisionVivo, idCanal, TituloCanal, Solicitud, Consulta, Pais]
# Index: []

# %%
columnasorden=['idRecursoVD','Titulo','Descripcion','TiempoPublicacion','TipoPrivacidad'\
               ,'idCanal','TituloCanal','Consulta','Pais','Solicitud']
DATA=mergedinner.reindex(columns=columnasorden)
DATA
# Out:
# Empty DataFrame
# Columns: [idRecursoVD, Titulo, Descripcion, TiempoPublicacion, TipoPrivacidad, idCanal, TituloCanal, Consulta, Pais, Solicitud]
# Index: []

# %% [markdown]
# #### Extraccion de datos

# %% [markdown]
# Se generan 4 nuevas columnas (emoticones, hashtags, URLs y menciones) por cada columna de texto importante. (En este caso 8)

# %% [markdown]
# ##### Extreaer emoticones

# %%
def emojis(texto):
  if (len(texto) != 0):
    emoji_summary = adv.extract_emoji(texto)
    return emoji_summary['top_emoji']
  else:
    L=[]
    return L

# %%
DATA['emojisTitulo']=DATA['Titulo'].apply(emojis)

# %%
DATA['emojisTitulo']
# Out:
# Series([], Name: emojisTitulo, dtype: float64)

# %%
DATA['emojisDescripcion']=DATA['Descripcion'].apply(emojis)

# %%
DATA['emojisDescripcion']
# Out:
# Series([], Name: emojisDescripcion, dtype: float64)

# %% [markdown]
# ##### Extraer URLs

# %%
extractor = URLExtract()
def URLs(texto):
  URL=extractor.find_urls(texto)
  return URL

# %%
DATA['URLsDescripcion']=DATA['Descripcion'].apply(URLs)
DATA['URLsTitulo']=DATA['Titulo'].apply(URLs)

# %%
DATA['URLsTitulo']
# Out:
# Series([], Name: URLsTitulo, dtype: float64)

# %%
DATA['URLsDescripcion']
# Out:
# Series([], Name: URLsDescripcion, dtype: float64)

# %% [markdown]
# ##### Quitar codigo hexadecimal ( \&quot; , &\#23; , etc) (Revizado)

# %%
def codigohex(texto):
  texto=html.unescape(texto)
  return texto

# %%
DATA['TituloModificado']=DATA['Titulo'].apply(codigohex)
DATA['DescripcionModificado']=DATA['Descripcion'].apply(codigohex)

# %% [markdown]
# ##### Extraer Hastags

# %%
def hastags(texto):
  pattern='#\w+'
  hastag=regexp_tokenize(texto,pattern)
  return hastag

# %%
DATA['hastagsDescripcion']=DATA['DescripcionModificado'].apply(hastags)
DATA['hastagsTitulo']=DATA['TituloModificado'].apply(hastags)

# %%
DATA['hastagsTitulo']
# Out:
# Series([], Name: hastagsTitulo, dtype: float64)

# %%
DATA['hastagsDescripcion']
# Out:
# Series([], Name: hastagsDescripcion, dtype: float64)

# %% [markdown]
# ##### Extraer menciones o etiquetas (puede ser necesario alguna modificacion para el caso de correos)

# %%
def mencion(texto):
  pattern='@\w+'
  mencion=regexp_tokenize(texto,pattern)
  return mencion

# %%
DATA['MencionesDescripcion']=DATA['Descripcion'].apply(mencion)
DATA['MencionesTitulo']=DATA['Titulo'].apply(mencion)

# %%
DATA['MencionesTitulo']
# Out:
# Series([], Name: MencionesTitulo, dtype: float64)

# %%
DATA['MencionesDescripcion']
# Out:
# Series([], Name: MencionesDescripcion, dtype: float64)

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   idRecursoVD            0 non-null      float64
#  1   Titulo                 0 non-null      float64
#  2   Descripcion            0 non-null      float64
#  3   TiempoPublicacion      0 non-null      float64
#  4   TipoPrivacidad         0 non-null      float64
#  5   idCanal                0 non-null      float64
#  6   TituloCanal            0 non-null      float64
#  7   Consulta               0 non-null      object
#  8   Pais                   0 non-null      object
#  9   Solicitud              0 non-null      int64
#  10  emojisTitulo           0 non-null      float64
#  11  emojisDescripcion      0 non-null      float64
#  12  URLsDescripcion        0 non-null      float64
#  13  URLsTitulo             0 non-null      float64
# ...

# %% [markdown]
# #### Limpiar texto: (Generamos una copia llamada columname_modificado de una columna a partir del cual vamos a realizar la limpieza de datos)

# %% [markdown]
# ##### Quitar codigo hexadecimal ( \&quot; , &\#23; , etc) (Revizado)

# %%
def codigohex(texto):
  texto=html.unescape(texto)
  return texto

# %%
DATA['TituloModificado']=DATA['Titulo'].apply(codigohex)
DATA['DescripcionModificado']=DATA['Descripcion'].apply(codigohex)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar Unicode (Es aca donde se eliminan las tildes-> Solucionado) NOTA: No se entiende muy bien que realiza este parte del codigo

# %%
def dropunicode(texto):
  texto = unicodedata.normalize('NFD', texto)
  texto=texto.encode('ascii','ignore').decode('utf8')
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropunicode)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropunicode)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar secuencias de escape

# %%
DATA['Titulo'] = DATA['Titulo'].apply(str.replace, args=('\r', ' '))
DATA['Titulo'] = DATA['Titulo'].apply(str.replace, args=('\n', ' '))
DATA['Titulo'] = DATA['Titulo'].apply(str.replace, args=('\v', ' '))
DATA['Titulo'] = DATA['Titulo'].apply(str.replace, args=('\t', ' '))
DATA['Titulo'] = DATA['Titulo'].apply(str.replace, args=('\f', ' '))
DATA['Titulo'] = DATA['Titulo'].apply(str.replace, args=('\b', ' '))
DATA['TituloModificado'] = DATA['TituloModificado'].apply(str.replace, args=('\r', ' '))
DATA['TituloModificado'] = DATA['TituloModificado'].apply(str.replace, args=('\n', ' '))
DATA['TituloModificado'] = DATA['TituloModificado'].apply(str.replace, args=('\v', ' '))
DATA['TituloModificado'] = DATA['TituloModificado'].apply(str.replace, args=('\t', ' '))
DATA['TituloModificado'] = DATA['TituloModificado'].apply(str.replace, args=('\f', ' '))
DATA['TituloModificado'] = DATA['TituloModificado'].apply(str.replace, args=('\b', ' '))
DATA['Descripcion'] = DATA['Descripcion'].apply(str.replace, args=('\r', ' '))
DATA['Descripcion'] = DATA['Descripcion'].apply(str.replace, args=('\n', ' '))
DATA['Descripcion'] = DATA['Descripcion'].apply(str.replace, args=('\v', ' '))
DATA['Descripcion'] = DATA['Descripcion'].apply(str.replace, args=('\t', ' '))
DATA['Descripcion'] = DATA['Descripcion'].apply(str.replace, args=('\f', ' '))
DATA['Descripcion'] = DATA['Descripcion'].apply(str.replace, args=('\b', ' '))
DATA['DescripcionModificado'] = DATA['DescripcionModificado'].apply(str.replace, args=('\r', ' '))
DATA['DescripcionModificado'] = DATA['DescripcionModificado'].apply(str.replace, args=('\n', ' '))
DATA['DescripcionModificado'] = DATA['DescripcionModificado'].apply(str.replace, args=('\v', ' '))
DATA['DescripcionModificado'] = DATA['DescripcionModificado'].apply(str.replace, args=('\t', ' '))
DATA['DescripcionModificado'] = DATA['DescripcionModificado'].apply(str.replace, args=('\f', ' '))
DATA['DescripcionModificado'] = DATA['DescripcionModificado'].apply(str.replace, args=('\b', ' '))

# %% [markdown]
# ##### Eliminar URLs

# %%
def dropURLs(texto):
  text = re.sub('https?://\S+|www\.\S+', ' ', texto)
  return text
def dropURL(texto):
  text = re.sub('http?://\S+|www\.\S+', ' ', texto)
  return text

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropURLs)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropURLs)
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropURL)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropURL)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar Emoticones

# %%
from cleantext import clean

# %%
from dataclasses import replace
def dropemoticons(texto):
  texto=clean(texto, no_emoji=True,lower=False)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropemoticons)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropemoticons)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar emails

# %%
def dropemails(texto):
  texto=clean(texto, no_emails=True, lower=False)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropemails)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropemails)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar Menciones

# %%
def dropmenciones(texto):
  texto = re.sub("@\S+", " ", texto)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropmenciones)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropmenciones)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Quitar caracteres repetidos

# %%
def droppalabrasrepetidas(texto):
  texto = re.sub(r'(.)\1{3,}',r'\1', texto)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(droppalabrasrepetidas)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(droppalabrasrepetidas)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar Numeros

# %%
def dropnumeros(texto):
  pattern = r'[0-9]'
  texto = re.sub(pattern, '', texto)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropnumeros)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropnumeros)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar \# de Hashtags

# %%
def dropnumeral(texto):
  texto = re.sub(r'#', ' ', texto)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropnumeral)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropnumeral)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Dividir palabras adjuntas (CamelCase)

# %%
def splitpalabras(texto):
  texto = " ".join([s for s in re.split("([A-Z][a-z]+[^A-Z]*)",texto) if s])
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(splitpalabras)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(splitpalabras)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar signos de puntuacion

# %%
punct = set(string.punctuation) 
punct
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
def puntuacion(texto):
  sinpuntuacion="".join([ch for ch in texto if ch not in punct])
  return sinpuntuacion

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(puntuacion)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(puntuacion)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar espacios

# %%
def dropespacios(texto):
  texto = re.sub('\s{2,}', " ", texto)
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(dropespacios)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(dropespacios)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Eliminar tokens cortos

# %%
def droppalabrascortas(texto):
  tokens = texto.split()
  clean_tokens = [t for t in tokens if len(t) > 1]
  clean_text = " ".join(clean_tokens)
  return clean_text

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(droppalabrascortas)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(droppalabrascortas)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Normalizar texto (Quitar mayusculas)

# %%
def normatext(texto):
  textonormalizado=texto.lower()
  return textonormalizado

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(normatext)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(normatext)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ##### Cambios particulares para cada serie

# %%
def cambiosEPM(texto):
  texto1=re.sub("elpatrondelmal", "el patron del mal", texto)
  texto2=re.sub("patrondelmal", "patron del mal", texto1)
  texto3=re.sub("patrondel", "patron del", texto2)
  texto4=re.sub("pabloescobar", "pablo escobar", texto3)
  texto5=re.sub("murtes", "muertes", texto4)
  texto6=re.sub("murte", "muerte", texto5)
  texto=re.sub("muerts", "muertes", texto6)  
  return texto

# %%
DATA['TituloModificado']=DATA['TituloModificado'].apply(cambiosEPM)
DATA['DescripcionModificado']=DATA['DescripcionModificado'].apply(cambiosEPM)

# %%
DATA['TituloModificado']
# Out:
# Series([], Name: TituloModificado, dtype: float64)

# %%
DATA['DescripcionModificado']
# Out:
# Series([], Name: DescripcionModificado, dtype: float64)

# %% [markdown]
# ====================== Vamos aca =================

# %% [markdown]
# #### Estructurar y dar formato

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   idRecursoVD            0 non-null      float64
#  1   Titulo                 0 non-null      float64
#  2   Descripcion            0 non-null      float64
#  3   TiempoPublicacion      0 non-null      float64
#  4   TipoPrivacidad         0 non-null      float64
#  5   idCanal                0 non-null      float64
#  6   TituloCanal            0 non-null      float64
#  7   Consulta               0 non-null      object
#  8   Pais                   0 non-null      object
#  9   Solicitud              0 non-null      int64
#  10  emojisTitulo           0 non-null      float64
#  11  emojisDescripcion      0 non-null      float64
#  12  URLsDescripcion        0 non-null      float64
#  13  URLsTitulo             0 non-null      float64
# ...

# %%
columnasorden=['idRecursoVD','Titulo','TituloModificado', 'emojisTitulo', 'URLsTitulo', 'hastagsTitulo','MencionesTitulo'\
               ,'Descripcion','DescripcionModificado', 'emojisDescripcion', 'URLsDescripcion', 'hastagsDescripcion','MencionesDescripcion','TiempoPublicacion','TipoPrivacidad'\
               ,'idCanal','TituloCanal','Consulta','Pais','Solicitud']

DATA=DATA.reindex(columns=columnasorden)
DATA
# Out:
# Empty DataFrame
# Columns: [idRecursoVD, Titulo, TituloModificado, emojisTitulo, URLsTitulo, hastagsTitulo, MencionesTitulo, Descripcion, DescripcionModificado, emojisDescripcion, URLsDescripcion, hastagsDescripcion, MencionesDescripcion, TiempoPublicacion, TipoPrivacidad, idCanal, TituloCanal, Consulta, Pais, Solicitud]
# Index: []

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   idRecursoVD            0 non-null      float64
#  1   Titulo                 0 non-null      float64
#  2   TituloModificado       0 non-null      float64
#  3   emojisTitulo           0 non-null      float64
#  4   URLsTitulo             0 non-null      float64
#  5   hastagsTitulo          0 non-null      float64
#  6   MencionesTitulo        0 non-null      float64
#  7   Descripcion            0 non-null      float64
#  8   DescripcionModificado  0 non-null      float64
#  9   emojisDescripcion      0 non-null      float64
#  10  URLsDescripcion        0 non-null      float64
#  11  hastagsDescripcion     0 non-null      float64
#  12  MencionesDescripcion   0 non-null      float64
#  13  TiempoPublicacion      0 non-null      float64
# ...

# %% [markdown]
# #### Exportar Dataframe a CSV

# %%
Metadatac.to_csv(PATH_TO_DIR_0+'/'+file_nameL+'.csv', index=False)
DATA.to_csv(PATH_TO_DIR_0+'/'+'RESULTS-'+file_nameL+'.csv', index=False)
