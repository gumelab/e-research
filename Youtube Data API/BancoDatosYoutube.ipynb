# %%
import pandas as pd 
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os 
from datetime import datetime, date

# %%
# ======================== OJO Modificar para cada serie ========================

pathCM='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
Narcos/Comentarios/RESULTS-PAISCOMENTARIOS-Lematizado2022-09-13 17_51_55.913996(Narcos).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfCM= pd.read_excel(pathCM)
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72493 entries, 0 to 72492
# Data columns (total 26 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idVideo                                          72493 non-null  object
#  1   idComentarioPrincipal                            72493 non-null  object
#  2   TextoComentarioPrincipal                         72490 non-null  object
#  3   FP/IM/CH/No (ComentarioPrincipal)                700 non-null    object
#  4   ComentarioPrincipal_Comentario1Gumelab           19 non-null     object
#  5   Idioma no útil                                   90 non-null     object
#  6   ComentarioPrincipal_Comentario2Gumelab           20 non-null     object
#  7   ComentarioPrincipalModificado                    72493 non-null  object
#  8   emojisComentarioPrincipal                        72493 non-null  object
# ...

# %%
dfCM
# Out:
#            idVideo       idComentarioPrincipal  \
# 0      NS8JbFvuTb4  UgzCxWFNA6dZNLaMVHF4AaABAg
# 1      NS8JbFvuTb4        UggpDwdh_GoZr3gCoAEC
# 2      NS8JbFvuTb4        UgjJ-eZxhsOPzXgCoAEC
# 3      NS8JbFvuTb4        UgiaTzlI9pYb0HgCoAEC
# 4      NS8JbFvuTb4        UgjADVVA9NaErXgCoAEC
# ...            ...                         ...
# 72488  Kw7NTEw1ilo  UgwRLwFItkt5bxP3CTV4AaABAg
# 72489  Kw7NTEw1ilo  UgwAqA0tzrT4YVPEX994AaABAg
# 72490  Kw7NTEw1ilo  UgycURaQpH7kRsBenLp4AaABAg
# 72491  Kw7NTEw1ilo  UgwRpQfsqW-9qoh27-h4AaABAg
# 72492  Kw7NTEw1ilo  UgzJGS6KOZpp__VCEt54AaABAg
#
#                                 TextoComentarioPrincipal  \
# 0                 la serie debería llamarse °parasitos°.
# 1      El Actor que encarna a Pablo Escobar tiene prá...
# 2                                                saludoz
# 3                                                saludoz
# 4                                                 saludo
# ...

# %%
dfCM_no= dfCM[dfCM["FP/IM/CH/No (ComentarioPrincipal)"] == "no"]
dfCM_no = dfCM_no[["idComentarioPrincipal","FP/IM/CH/No (ComentarioPrincipal)"]]
dfCM_fp= dfCM[dfCM["FP/IM/CH/No (ComentarioPrincipal)"] == "FP"]
dfCM_fp = dfCM_fp[["idComentarioPrincipal","FP/IM/CH/No (ComentarioPrincipal)"]]
dfCM_ch= dfCM[dfCM["FP/IM/CH/No (ComentarioPrincipal)"] == "CH"]
dfCM_ch = dfCM_ch[["idComentarioPrincipal","FP/IM/CH/No (ComentarioPrincipal)"]]
dfCM_im= dfCM[dfCM["FP/IM/CH/No (ComentarioPrincipal)"] == "IM"]
dfCM_im = dfCM_im[["idComentarioPrincipal","FP/IM/CH/No (ComentarioPrincipal)"]]

# %%
dfCM_no = dfCM_no.rename(columns={'FP/IM/CH/No (ComentarioPrincipal)':'No (ComentarioPrincipal)'})
dfCM_fp = dfCM_fp.rename(columns={'FP/IM/CH/No (ComentarioPrincipal)':'FP (ComentarioPrincipal)'})
dfCM_ch = dfCM_ch.rename(columns={'FP/IM/CH/No (ComentarioPrincipal)':'CH (ComentarioPrincipal)'})
dfCM_im = dfCM_im.rename(columns={'FP/IM/CH/No (ComentarioPrincipal)':'IM (ComentarioPrincipal)'})

# %%
dfCM_no
# Out:
#           idComentarioPrincipal No (ComentarioPrincipal)
# 2          UgjJ-eZxhsOPzXgCoAEC                       no
# 3          UgiaTzlI9pYb0HgCoAEC                       no
# 4          UgjADVVA9NaErXgCoAEC                       no
# 5          Ugj_t5TKHawCXHgCoAEC                       no
# 10   Ugzs9iuTUnoqU-cSgU14AaABAg                       no
# ..                          ...                      ...
# 695        UggZhj0pA2O9nHgCoAEC                       no
# 696        UggwIm20UecyAngCoAEC                       no
# 697        UghvYAZHhqdPd3gCoAEC                       no
# 698        UghafWvTA2XaIngCoAEC                       no
# 699        UgiXTv9_SyaqAngCoAEC                       no
#
# [661 rows x 2 columns]

# %%
dfCM_fp
# Out:
#           idComentarioPrincipal FP (ComentarioPrincipal)
# 0    UgzCxWFNA6dZNLaMVHF4AaABAg                       FP
# 1          UggpDwdh_GoZr3gCoAEC                       FP
# 7          UgjHEATdLrzZJXgCoAEC                       FP
# 23   Ugy7QZ8WFqrXC8lkWH14AaABAg                       FP
# 25   Ugywgmedj4GMTkdYDv54AaABAg                       FP
# 26   UgxUN5CUZvtAxlGmS3F4AaABAg                       FP
# 81         Ugh5DLYhloY4mngCoAEC                       FP
# 201        UggQkf5yBH6DsngCoAEC                       FP
# 211  UgwwJMQMLz495IoPNe14AaABAg                       FP
# 251        UgjHL9PcTuXigHgCoAEC                       FP
# 335  UgwruZ09WhHSjc2w5pZ4AaABAg                       FP
# 336  UgyDoE2pONw8WXfiEel4AaABAg                       FP
# 337  UgwZS4e1PunQvNDPmep4AaABAg                       FP
# 391        UgiTdcG8DspfLngCoAEC                       FP
# 392        Ugh1sAZ0iuXKIngCoAEC                       FP
# ...

# %%
dfCM_ch
# Out:
#           idComentarioPrincipal CH (ComentarioPrincipal)
# 6          UggnIdNTYWlgYngCoAEC                       CH
# 8          UgjydedGkrc0L3gCoAEC                       CH
# 9    UgzE5DFM39wZCrEjEPV4AaABAg                       CH
# 24   UgwzFq_xgJsTLITlsfh4AaABAg                       CH
# 28   Ugzbk2p_Y2T7VvNylv54AaABAg                       CH
# 79         Ugi_IYFw4md1hXgCoAEC                       CH
# 343        UgjBXvWnqzzCcHgCoAEC                       CH
# 388        UggbI2cTFzmh03gCoAEC                       CH
# 647  Ugzam6aUY3te2vreAZd4AaABAg                       CH
# 673  UgxaSBvLfu3Z7EzUXHV4AaABAg                       CH

# %%
dfCM_im
# Out:
# Empty DataFrame
# Columns: [idComentarioPrincipal, IM (ComentarioPrincipal)]
# Index: []

# %%
dfCM = pd.merge(left=dfCM, right=dfCM_no, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
dfCM = pd.merge(left=dfCM, right=dfCM_fp, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
dfCM = pd.merge(left=dfCM, right=dfCM_ch, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
dfCM = pd.merge(left=dfCM, right=dfCM_im, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72493 entries, 0 to 72492
# Data columns (total 30 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idVideo                                          72493 non-null  object
#  1   idComentarioPrincipal                            72493 non-null  object
#  2   TextoComentarioPrincipal                         72490 non-null  object
#  3   FP/IM/CH/No (ComentarioPrincipal)                700 non-null    object
#  4   ComentarioPrincipal_Comentario1Gumelab           19 non-null     object
#  5   Idioma no útil                                   90 non-null     object
#  6   ComentarioPrincipal_Comentario2Gumelab           20 non-null     object
#  7   ComentarioPrincipalModificado                    72493 non-null  object
#  8   emojisComentarioPrincipal                        72493 non-null  object
# ...

# %%
dfCM
# Out:
#            idVideo       idComentarioPrincipal  \
# 0      NS8JbFvuTb4  UgzCxWFNA6dZNLaMVHF4AaABAg
# 1      NS8JbFvuTb4        UggpDwdh_GoZr3gCoAEC
# 2      NS8JbFvuTb4        UgjJ-eZxhsOPzXgCoAEC
# 3      NS8JbFvuTb4        UgiaTzlI9pYb0HgCoAEC
# 4      NS8JbFvuTb4        UgjADVVA9NaErXgCoAEC
# ...            ...                         ...
# 72488  Kw7NTEw1ilo  UgwRLwFItkt5bxP3CTV4AaABAg
# 72489  Kw7NTEw1ilo  UgwAqA0tzrT4YVPEX994AaABAg
# 72490  Kw7NTEw1ilo  UgycURaQpH7kRsBenLp4AaABAg
# 72491  Kw7NTEw1ilo  UgwRpQfsqW-9qoh27-h4AaABAg
# 72492  Kw7NTEw1ilo  UgzJGS6KOZpp__VCEt54AaABAg
#
#                                 TextoComentarioPrincipal  \
# 0                 la serie debería llamarse °parasitos°.
# 1      El Actor que encarna a Pablo Escobar tiene prá...
# 2                                                saludoz
# 3                                                saludoz
# 4                                                 saludo
# ...

# %%
PATH_TO_SAVE_SEARCHES = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/Narcos/Comentarios'

# %%
dfCM.to_excel(PATH_TO_SAVE_SEARCHES+'/'+'RESULTSComentariosNarcos(SplitColumns)-.xlsx', index=False)

# %%
# ======================== OJO Modificar para cada serie ========================

pathCM='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
Narcos/RespuestasComentarios/RESULTS-PAISCOMENTARIOS-Lematizado2022-09-14 16_27_41.290355(Narcos).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfCM= pd.read_excel(pathCM)
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44752 entries, 0 to 44751
# Data columns (total 21 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idComentarioPrincipal                            44752 non-null  object
#  1   idComentarioRespuesta                            44752 non-null  object
#  2   TextoComentarioRespuesta                         44752 non-null  object
#  3   FP/IM/CH/No (ComentarioRespuesta)                1015 non-null   object
#  4   ComentarioRespuesta_ComentarioGumelab            98 non-null     object
#  5   ComentarioRespuestaModificado                    44752 non-null  object
#  6   emojisComentarioRespuesta                        44752 non-null  object
#  7   URLsComentarioRespuesta                          44752 non-null  object
#  8   hashtagsComentarioRespuesta                      44752 non-null  object
# ...

# %%
dfCM
# Out:
#             idComentarioPrincipal  \
# 0      UgwlPhxYTBD-55gOB4V4AaABAg
# 1            Ugg_RKo21_vrZHgCoAEC
# 2            Ugg_RKo21_vrZHgCoAEC
# 3            UggyBUjrgKh5EngCoAEC
# 4      Ugzbk2p_Y2T7VvNylv54AaABAg
# ...                           ...
# 44747  UgzJGS6KOZpp__VCEt54AaABAg
# 44748  UgzJGS6KOZpp__VCEt54AaABAg
# 44749  UgzJGS6KOZpp__VCEt54AaABAg
# 44750  UgzJGS6KOZpp__VCEt54AaABAg
# 44751  UgzJGS6KOZpp__VCEt54AaABAg
#
#                                    idComentarioRespuesta  \
# 0      UgwlPhxYTBD-55gOB4V4AaABAg.9A9xvko1h_D9AItau7yMfv
# 1            Ugg_RKo21_vrZHgCoAEC.8UfoD0RFm0W8W2zp9ngCIZ
# 2            Ugg_RKo21_vrZHgCoAEC.8UfoD0RFm0W8W0Hq9rYYAy
# 3            UggyBUjrgKh5EngCoAEC.8J4_QQ-wOKM8J4c42SEh7K
# 4      Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q9G5W7gq1Dlv
# ...                                                  ...
# 44747  UgzJGS6KOZpp__VCEt54AaABAg.9ISllMnUxIx9KdpRC_UORM
# 44748  UgzJGS6KOZpp__VCEt54AaABAg.9ISllMnUxIx9Jb3DECqmlf
# ...

# %%
dfCM_no= dfCM[dfCM["FP/IM/CH/No (ComentarioRespuesta)"] == "no"]
dfCM_no = dfCM_no[["idComentarioRespuesta","FP/IM/CH/No (ComentarioRespuesta)"]]
dfCM_fp= dfCM[dfCM["FP/IM/CH/No (ComentarioRespuesta)"] == "FP"]
dfCM_fp = dfCM_fp[["idComentarioRespuesta","FP/IM/CH/No (ComentarioRespuesta)"]]
dfCM_ch= dfCM[dfCM["FP/IM/CH/No (ComentarioRespuesta)"] == "CH"]
dfCM_ch = dfCM_ch[["idComentarioRespuesta","FP/IM/CH/No (ComentarioRespuesta)"]]
dfCM_im= dfCM[dfCM["FP/IM/CH/No (ComentarioRespuesta)"] == "IM"]
dfCM_im = dfCM_im[["idComentarioRespuesta","FP/IM/CH/No (ComentarioRespuesta)"]]

# %%
dfCM_no = dfCM_no.rename(columns={'FP/IM/CH/No (ComentarioRespuesta)':'No (ComentarioRespuesta)'})
dfCM_fp = dfCM_fp.rename(columns={'FP/IM/CH/No (ComentarioRespuesta)':'FP (ComentarioRespuesta)'})
dfCM_ch = dfCM_ch.rename(columns={'FP/IM/CH/No (ComentarioRespuesta)':'CH (ComentarioRespuesta)'})
dfCM_im = dfCM_im.rename(columns={'FP/IM/CH/No (ComentarioRespuesta)':'IM (ComentarioRespuesta)'})

# %%
dfCM_no
# Out:
#                                   idComentarioRespuesta  \
# 0     UgwlPhxYTBD-55gOB4V4AaABAg.9A9xvko1h_D9AItau7yMfv
# 1           Ugg_RKo21_vrZHgCoAEC.8UfoD0RFm0W8W2zp9ngCIZ
# 2           Ugg_RKo21_vrZHgCoAEC.8UfoD0RFm0W8W0Hq9rYYAy
# 3           UggyBUjrgKh5EngCoAEC.8J4_QQ-wOKM8J4c42SEh7K
# 9           UghdcAFnOV12KXgCoAEC.8V-UDyG4fG28V-UMHTFsSD
# ...                                                 ...
# 1010  UgygGmIxsNaPF49p4PZ4AaABAg.8X9Nn0-T2po9EBbbuZ6ZTv
# 1011  UgygGmIxsNaPF49p4PZ4AaABAg.8X9Nn0-T2po8cG1dY0aT7Z
# 1012        Ugh2Igk2DT3HEXgCoAEC.8Ve1_gjYUJZ8_ybB3PxzQp
# 1013        UginW1d_5lranHgCoAEC.8V9OEoOCHZK9OJS_rzRPvU
# 1014  Ugw0O_a5pQAvcXQLMhN4AaABAg.8QTXlblwVWW8_p8X7rOFOV
#
#      No (ComentarioRespuesta)
# 0                          no
# 1                          no
# 2                          no
# 3                          no
# 9                          no
# ...                       ...
# 1010                       no
# 1011                       no
# ...

# %%
dfCM_fp
# Out:
#                                  idComentarioRespuesta  \
# 5    Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q9G5VCzhXgQx
# 6    Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q9G5UJXeS1wn
# 7    Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q9BD_r2d-lnk
# 8    Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q99GSrVBsXVL
# 260  UgwsrddwrCrmTcMB_oN4AaABAg.9PPH0_UmZoK9Pk9ZbrGdt3
# 268  UgyA_SaW9x4mSJwoSzR4AaABAg.9PMPg4BvQoB9RBoN9o_oeh
# 271  UgyA_SaW9x4mSJwoSzR4AaABAg.9PMPg4BvQoB9R9Ii_VO0FT
# 277  Ugzmab5MzSnVVx4tnuN4AaABAg.9PLdRmenSIo9PSqBxOhYuG
# 593  UgxLvBiVFyFCPDsreI94AaABAg.8VlT7uoA1-L8YuSKoUtCGp
# 599        Ugj-abEqnVB8wHgCoAEC.8UG2a_sOKC09-g1DJhLREv
# 600        Ugj-abEqnVB8wHgCoAEC.8UG2a_sOKC08xml_Yr4g86
# 601        Ugj-abEqnVB8wHgCoAEC.8UG2a_sOKC08etUcPleh9Q
# 602        Ugj-abEqnVB8wHgCoAEC.8UG2a_sOKC08b8uUiStd21
# 605        UggGYJlluLCJHXgCoAEC.8PVZZwmU8O38gaUBmzacwK
# 607        Ugit16GdTofLiHgCoAEC.8KB3nDond3A8a_qfjAEjPX
# 608        UggSGVvoYQUCZ3gCoAEC.8K4AC3qr4XG8ds4qOarj1f
# ...

# %%
dfCM_ch
# Out:
#                                  idComentarioRespuesta  \
# 4    Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q9G5W7gq1Dlv
# 278  Ugzmab5MzSnVVx4tnuN4AaABAg.9PLdRmenSIo9PRlGTGNztI
# 283  UgwjlNXiHhKHySVuDTN4AaABAg.9PLSRWkmIY09PQI-92i9Cc
# 284  UgzGrfuhv-023HeXwV54AaABAg.9PLDJKpf0H29PRlTgjseit
# 285  UgzGrfuhv-023HeXwV54AaABAg.9PLDJKpf0H29PLo6cKPj7Q
# 478  Ugzam6aUY3te2vreAZd4AaABAg.8j07wFQEKLi96qkdi3bxdU
# 480        UghUZ60qDMduPngCoAEC.8KV_F0tWOwF8KbSMZsxqlp
# 598        Ugj-abEqnVB8wHgCoAEC.8UG2a_sOKC09-ujeuwqjUg
# 639  UgyBrtnN7adXhqtspJd4AaABAg.9Nk_NAW97XG9O9COHspj-2
# 654  UgyIJ5mmNJncXoYgiQt4AaABAg.9OaYmXr8mti9PdWOWo03ms
# 655  UgyIJ5mmNJncXoYgiQt4AaABAg.9OaYmXr8mti9OsJeJ_apx3
# 657  UgyIJ5mmNJncXoYgiQt4AaABAg.9OaYmXr8mti9OlEiR9iWPZ
# 665  UgzTRUXkQdEyMAal90t4AaABAg.9ONQydT0I5k9OO0tPYIJH7
# 682  UgxwUxl7vSpM3W0lUGl4AaABAg.9Mvf3FMgkLq9NE41LyRus1
# 689  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9WJsPD5Wm37
# 690  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9SRYpOBXJ7O
# ...

# %%
dfCM_im
# Out:
# Empty DataFrame
# Columns: [idComentarioRespuesta, IM (ComentarioRespuesta)]
# Index: []

# %%
dfCM = pd.merge(left=dfCM, right=dfCM_no, how="left", left_on='idComentarioRespuesta', right_on='idComentarioRespuesta')
dfCM = pd.merge(left=dfCM, right=dfCM_fp, how="left", left_on='idComentarioRespuesta', right_on='idComentarioRespuesta')
dfCM = pd.merge(left=dfCM, right=dfCM_ch, how="left", left_on='idComentarioRespuesta', right_on='idComentarioRespuesta')
dfCM = pd.merge(left=dfCM, right=dfCM_im, how="left", left_on='idComentarioRespuesta', right_on='idComentarioRespuesta')
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44752 entries, 0 to 44751
# Data columns (total 25 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idComentarioPrincipal                            44752 non-null  object
#  1   idComentarioRespuesta                            44752 non-null  object
#  2   TextoComentarioRespuesta                         44752 non-null  object
#  3   FP/IM/CH/No (ComentarioRespuesta)                1015 non-null   object
#  4   ComentarioRespuesta_ComentarioGumelab            98 non-null     object
#  5   ComentarioRespuestaModificado                    44752 non-null  object
#  6   emojisComentarioRespuesta                        44752 non-null  object
#  7   URLsComentarioRespuesta                          44752 non-null  object
#  8   hashtagsComentarioRespuesta                      44752 non-null  object
# ...

# %%
dfCM
# Out:
#             idComentarioPrincipal  \
# 0      UgwlPhxYTBD-55gOB4V4AaABAg
# 1            Ugg_RKo21_vrZHgCoAEC
# 2            Ugg_RKo21_vrZHgCoAEC
# 3            UggyBUjrgKh5EngCoAEC
# 4      Ugzbk2p_Y2T7VvNylv54AaABAg
# ...                           ...
# 44747  UgzJGS6KOZpp__VCEt54AaABAg
# 44748  UgzJGS6KOZpp__VCEt54AaABAg
# 44749  UgzJGS6KOZpp__VCEt54AaABAg
# 44750  UgzJGS6KOZpp__VCEt54AaABAg
# 44751  UgzJGS6KOZpp__VCEt54AaABAg
#
#                                    idComentarioRespuesta  \
# 0      UgwlPhxYTBD-55gOB4V4AaABAg.9A9xvko1h_D9AItau7yMfv
# 1            Ugg_RKo21_vrZHgCoAEC.8UfoD0RFm0W8W2zp9ngCIZ
# 2            Ugg_RKo21_vrZHgCoAEC.8UfoD0RFm0W8W0Hq9rYYAy
# 3            UggyBUjrgKh5EngCoAEC.8J4_QQ-wOKM8J4c42SEh7K
# 4      Ugzbk2p_Y2T7VvNylv54AaABAg.99FEQVaCS6q9G5W7gq1Dlv
# ...                                                  ...
# 44747  UgzJGS6KOZpp__VCEt54AaABAg.9ISllMnUxIx9KdpRC_UORM
# 44748  UgzJGS6KOZpp__VCEt54AaABAg.9ISllMnUxIx9Jb3DECqmlf
# ...

# %%
PATH_TO_SAVE_SEARCHES = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/Narcos/RespuestasComentarios'

# %%
dfCM.to_excel(PATH_TO_SAVE_SEARCHES+'/'+'RESULTSRespuestasComentariosNarcos(SplitColumns)-.xlsx', index=False)

# %%
path_etiquetas_youtube = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/EtiquetasYoutubeGumelab/\
Youtube_IM,FP,CH_22.12.22.xlsx'

# %%
etiquetas_fp = pd.read_excel(path_etiquetas_youtube, sheet_name= "FP")
etiquetas_fp=etiquetas_fp[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]

# %%
etiquetas_fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idVideo                   191 non-null    object
#  1   idComentarioPrincipal     191 non-null    object
#  2   TextoComentarioPrincipal  191 non-null    object
#  3   IM, FP, CH                191 non-null    object
# dtypes: object(4)
# memory usage: 6.1+ KB

# %%
etiquetas_ch = pd.read_excel(path_etiquetas_youtube, sheet_name= "CH")
etiquetas_ch=etiquetas_ch[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]

# %%
etiquetas_ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idVideo                   141 non-null    object
#  1   idComentarioPrincipal     141 non-null    object
#  2   TextoComentarioPrincipal  141 non-null    object
#  3   IM, FP, CH                140 non-null    object
# dtypes: object(4)
# memory usage: 4.5+ KB

# %%
etiquetas_ch
# Out:
#                         idVideo  \
# 0                   ADuMNEja1dQ
# 1                   NNZI4hX_4rM
# 2                   NNZI4hX_4rM
# 3                   ofjZvLSudxo
# 4                   ofjZvLSudxo
# ..                          ...
# 136  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 137  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 138  Ugw0GgPvcqKIqjJP2lx4AaABAg
# 139        UgjdNZjbN4cMRXgCoAEC
# 140        UgjdNZjbN4cMRXgCoAEC
#
#                                  idComentarioPrincipal  \
# 0                           UgzgDoJ9XU6RaBnLs9Z4AaABAg
# 1                           UgwcL7GOp6tw0tsFuON4AaABAg
# 2                           Ugy4ZgHW1Jhl6rxNMYt4AaABAg
# 3                           Ugzmu9E3ElYLssnHWyV4AaABAg
# 4                           UgyfUobYNrLXp3khStJ4AaABAg
# ..                                                 ...
# 136  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9PdHDZ0J_Ow
# 137  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9PdE_ak_kuK
# 138  Ugw0GgPvcqKIqjJP2lx4AaABAg.9MqC92yOJ8L9Oh40ulZWrn
# ...

# %%
etiquetas_im = pd.read_excel(path_etiquetas_youtube, sheet_name= "IM")
etiquetas_im=etiquetas_im[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]

# %%
etiquetas_im.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idVideo                   172 non-null    object
#  1   idComentarioPrincipal     172 non-null    object
#  2   TextoComentarioPrincipal  172 non-null    object
#  3   IM, FP, CH                165 non-null    object
# dtypes: object(4)
# memory usage: 5.5+ KB

# %%
etiquetas_im
# Out:
#          idVideo       idComentarioPrincipal  \
# 0    fhb3Ms3Mj8s  UgzhOuz_gV7AG6n-gqB4AaABAg
# 1    fhb3Ms3Mj8s  UgyX63qpkYN0jA8a0OJ4AaABAg
# 2    fhb3Ms3Mj8s  Ugw1V9tECDUchWT3unB4AaABAg
# 3    fhb3Ms3Mj8s  UgzMPVkU8XFDbb8ciDV4AaABAg
# 4    41c8e5JrDwQ  UgzRR0r0Q6DPP0nyct54AaABAg
# ..           ...                         ...
# 168  sUMU9Nul86o  Ugzd0wtQAl_srx1q5054AaABAg
# 169  sUMU9Nul86o  UgxnW_YumRIBdXeYoLh4AaABAg
# 170  sUMU9Nul86o  UgzzGqMDa2ni2RqjyAV4AaABAg
# 171  sUMU9Nul86o  UgwNY9oD7VlbpjJwVfd4AaABAg
# 172  sUMU9Nul86o  Ugy4BrfhYn1snws-Z7B4AaABAg
#
#                               TextoComentarioPrincipal IM, FP, CH
# 0    Ese 1tres de agosto de 1999 nos mataron un poc...         IM
# 1    Jaime Garzón era un humorista Colombiano que s...         IM
# 2    Jaime!!! Cuanta razon tenias y cuan indiferent...         IM
# 3    para todos los presentes jairo garcia es JAIME...         IM
# 4    Sr Campeche historiador Hoy van en el capítulo...         IM
# ...

# %%
etiquetas_no = pd.read_excel(path_etiquetas_youtube, sheet_name= "No")
etiquetas_no = etiquetas_no[["idVideo","idComentarioPrincipal","TextoComentarioPrincipal","IM, FP, CH"]]

# %%
etiquetas_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idVideo                   736 non-null    object
#  1   idComentarioPrincipal     736 non-null    object
#  2   TextoComentarioPrincipal  736 non-null    object
#  3   IM, FP, CH                736 non-null    object
# dtypes: object(4)
# memory usage: 23.1+ KB

# %%
etiquetas_no
# Out:
#          idVideo       idComentarioPrincipal  \
# 0    i_6E10appCA  UgzBsMN6pxgQY2K5lz54AaABAg
# 1    i_6E10appCA  UgyVd0DyUTf_OiE9IK54AaABAg
# 2    i_6E10appCA  UgwurYvZu5q2W20drzB4AaABAg
# 3    i_6E10appCA  Ugx-lg8zr0L_XpyJmld4AaABAg
# 4    i_6E10appCA  Ugy83UUMZHG-LTErB3N4AaABAg
# ..           ...                         ...
# 731  fhb3Ms3Mj8s  UgxcD4wJylCeA9qnyZJ4AaABAg
# 732  fhb3Ms3Mj8s  UgzuNvLqutfUQ-zPjHh4AaABAg
# 733  fhb3Ms3Mj8s  UgzO7Ypqv9ytju7pCbh4AaABAg
# 734  fhb3Ms3Mj8s  UgwAS8IH7xmEO2oVTkR4AaABAg
# 735  4BAC0lBLtYw  UgyBYBIUvUiHu4324F94AaABAg
#
#                               TextoComentarioPrincipal IM, FP, CH
# 0                                Buenísima la serie!!!         no
# 1    en la vida real, aeste asesino y violador Paul...         no
# 2    Llegaron el año 1961 a Parral (camino a Catill...         no
# 3    la vere ahora por cuevana xddd no tengo amazon...         no
# 4                                           Sos el 1❤️         no
# ...

# %% [markdown]
# # Importamos videos de series de youtube

# %%
# ======================== OJO Modificar para cada serie ========================

pathVD='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
EscobarPatrondelMal/Videos/DataVideoTotal(EscobarPatrondelMal).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfVD= pd.read_excel(pathVD)
dfVD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idVideo                 1974 non-null   object
#  1   TituloVideo             1974 non-null   object
#  2   DescripcionVideo        1679 non-null   object
#  3   FechaPublicacionVideo   1974 non-null   object
#  4   VistasVideo             1974 non-null   int64
#  5   LikesVideo              1963 non-null   float64
#  6   ComentariosVideo        1965 non-null   float64
#  7   ConsultaVideo           1974 non-null   object
#  8   PaisVideo               1974 non-null   object
#  9   UtilVideoSi_No          343 non-null    object
#  10  ComentarioVideoGumelab  9 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 169.8+ KB

# %%
dfVD=dfVD.drop(columns=['TituloVideoModificado','emojisTituloVideo','URLsTituloVideo','hashtagsTituloVideo','MencionesTituloVideo'\
                        ,'DescripcionVideoModificado','emojisDescripcionVideo','URLsDescripcionVideo','hashtagsDescripcionVideo','MencionesDescripcionVideo'\
                        ,'CategoriaVideo','FavoritoVideo','EtiquetasVideo','EtiquetasVideoTexto','TransmisionVivoVideo','idCanalVideo','TituloCanalVideo','ConsultaVideoModificado','SolicitudVideo'\
                        ,'TituloEtiquetasVideo','TotalTextoVideoModificado','Cos(BolsaPalabras)','Cos(TF_IDF)','Cos(Ngrams)','Relevancia','ConsultaVideoModificadoLematizadoProfundo','TotalTextoVideoModificadoLematizadoProfundo']) # RelevanciaxPalabra o Relevancia'''

# %%
dfVD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idVideo                 1974 non-null   object
#  1   TituloVideo             1974 non-null   object
#  2   DescripcionVideo        1679 non-null   object
#  3   FechaPublicacionVideo   1974 non-null   object
#  4   VistasVideo             1974 non-null   int64
#  5   LikesVideo              1963 non-null   float64
#  6   ComentariosVideo        1965 non-null   float64
#  7   ConsultaVideo           1974 non-null   object
#  8   PaisVideo               1974 non-null   object
#  9   UtilVideoSi_No          343 non-null    object
#  10  ComentarioVideoGumelab  9 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 169.8+ KB

# %%
dfVD=dfVD.assign(UtilVideoSi_No="",ComentarioVideoGumelab="")

# %%
dfVD
# Out:
#           idVideo                                        TituloVideo  \
# 0     KyqdbQW3pcg  Quien es quien en la la serie escobar el patro...
# 1     VfW5EtBscbc  Opinión Serie Pablo Escobar, ''el patrón del m...
# 2     k2TeK3a2Y2E             Série Pablo Escobar " Patron del Mal "
# 3     i7RBeP5kzTE      Intro serie pablo escobar "el patron del mal"
# 4     uymQfLPZZAQ  Representación serie Pablo Escobar el patrón d...
# ...           ...                                                ...
# 1969  TdS9S57Knac                       detras de camaras de escobar
# 1970  qAgvcUghU3U  Como fue la captura de Marcos Herber? | Pablo ...
# 1971  pylto493Zxg                  Pablo Escobar, The Drug Lord Ep 1
# 1972  ecMRHx3snTw                  Pablo Escobar, The Drug Lord Demo
# 1973  4dfaXMxefgs  Higuita enfrenta al ayudante de Pablo Escobar ...
#
#                                        DescripcionVideo FechaPublicacionVideo  \
# ...

# %%
dfVD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idVideo                 1974 non-null   object
#  1   TituloVideo             1974 non-null   object
#  2   DescripcionVideo        1679 non-null   object
#  3   FechaPublicacionVideo   1974 non-null   object
#  4   VistasVideo             1974 non-null   int64
#  5   LikesVideo              1963 non-null   float64
#  6   ComentariosVideo        1965 non-null   float64
#  7   ConsultaVideo           1974 non-null   object
#  8   PaisVideo               1974 non-null   object
#  9   UtilVideoSi_No          343 non-null    object
#  10  ComentarioVideoGumelab  9 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 169.8+ KB

# %% [markdown]
# # Importamos comentarios de series de youtube

# %%
# ======================== OJO Modificar para cada serie ========================

pathCM='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
EscobarPatrondelMal/Comentarios/RESULTS-PAISCOMENTARIOS-Lematizado2022-09-09 14_53_41.630106(EscobarPatrondelMal).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfCM= pd.read_excel(pathCM)
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105386 entries, 0 to 105385
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   idVideo                                          105386 non-null  object
#  1   idComentarioPrincipal                            105386 non-null  object
#  2   TextoComentarioPrincipal                         105335 non-null  object
#  3   FP/IM/CH/No (ComentarioPrincipal)                0 non-null       float64
#  4   ComentarioPrincipalModificado                    105386 non-null  object
#  5   emojisComentarioPrincipal                        105386 non-null  object
#  6   URLsComentarioPrincipal                          105386 non-null  object
#  7   hashtagsComentarioPrincipal                      105386 non-null  object
#  8   MencionesComentarioPrincipal                     105386 non-null  object
# ...

# %%
dfCM=dfCM.drop(columns=['ComentarioPrincipalModificado','emojisComentarioPrincipal','URLsComentarioPrincipal','hashtagsComentarioPrincipal','MencionesComentarioPrincipal'\
                        ,'PublicoComentarioPrincipal','ReplicarComentarioPrincipal','URLAutorCanalComentarioPrincipal','idAutorCanalComentarioPrincipal','CalificacionEspectadorComentarioPrincipal'\
                        ,'CalificarComentarioPrincipal','SolicitudComentarioPrincipal','ComentarioPrincipalModificadoLematizadoProfundo'])

# %%
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105386 entries, 0 to 105385
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   idVideo                                105386 non-null  object
#  1   idComentarioPrincipal                  105386 non-null  object
#  2   TextoComentarioPrincipal               105335 non-null  object
#  3   FP/IM/CH/No (ComentarioPrincipal)      0 non-null       float64
#  4   LikesComentarioPrincipal               105386 non-null  float64
#  5   ReplicasTotalesComentarioPrincipal     105386 non-null  float64
#  6   FechaPublicacionComentarioPrincipal    105386 non-null  object
#  7   FechaActualizacionComentarioPrincipal  105386 non-null  object
#  8   NombreAutorComentarioPrincipal         105381 non-null  object
#  9   PaisComentarioPrincipal                6551 non-null    object
# dtypes: float64(3), object(7)
# ...

# %%
dfCM=dfCM.assign(UtilComentarioPrincipalSi_No="") # solo para narcos

# %%
dfCM=dfCM.assign(UtilComentarioPrincipalSi_No="",ComentarioPrincipal_ComentarioGumelab="")

# %%
dfCM.insert(4, "FP (ComentarioPrincipal)", value="")
dfCM.insert(5, "IM (ComentarioPrincipal)", value="")
dfCM.insert(6, "CH (ComentarioPrincipal)", value="")
dfCM.insert(7, "No (ComentarioPrincipal)", value="")

# %%
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105386 entries, 0 to 105385
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   idVideo                                105386 non-null  object
#  1   idComentarioPrincipal                  105386 non-null  object
#  2   TextoComentarioPrincipal               105335 non-null  object
#  3   FP/IM/CH/No (ComentarioPrincipal)      0 non-null       float64
#  4   FP (ComentarioPrincipal)               105386 non-null  object
#  5   IM (ComentarioPrincipal)               105386 non-null  object
#  6   CH (ComentarioPrincipal)               105386 non-null  object
#  7   No (ComentarioPrincipal)               105386 non-null  object
#  8   LikesComentarioPrincipal               105386 non-null  float64
#  9   ReplicasTotalesComentarioPrincipal     105386 non-null  float64
# ...

# %%
dfCM=dfCM.drop(['FP/IM/CH/No (ComentarioPrincipal)'], axis=1)

# %%
dfCM
# Out:
#             idVideo       idComentarioPrincipal  \
# 0       VfW5EtBscbc  Ugz-p0n67DppB3RyeOx4AaABAg
# 1       MJ1x3KMTuv0  UgyRC-WEFsifvxz5kYp4AaABAg
# 2       JiFjQ2v_MgI  Ugwy9suVxVo558xs0_h4AaABAg
# 3       JiFjQ2v_MgI  UgxuooHBu50FsMzq8kd4AaABAg
# 4       JiFjQ2v_MgI  UgzC8Rm2QCEGpHyj9dZ4AaABAg
# ...             ...                         ...
# 105381  4dfaXMxefgs        Uggiz61X0vPWMngCoAEC
# 105382  4dfaXMxefgs        Ugil0lRXcaX47ngCoAEC
# 105383  4dfaXMxefgs        Ugi2tS9-NQiuLngCoAEC
# 105384  4dfaXMxefgs  UgwtpCGv0YKFvY9RPFN4AaABAg
# 105385  4dfaXMxefgs  UgyhMXTUxR-ThYhzUCF4AaABAg
#
#                                  TextoComentarioPrincipal  \
# 0                                      Mándame saludos!!!
# 1                                              Primero xd
# 2       Pablo escobar no era el patrón del mal si no d...
# 3                    Aún que dicen que el no mato a galán
# 4                                                       😼
# ...

# %%
dfCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105386 entries, 0 to 105385
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   idVideo                                105386 non-null  object
#  1   idComentarioPrincipal                  105386 non-null  object
#  2   TextoComentarioPrincipal               105335 non-null  object
#  3   FP (ComentarioPrincipal)               105386 non-null  object
#  4   IM (ComentarioPrincipal)               105386 non-null  object
#  5   CH (ComentarioPrincipal)               105386 non-null  object
#  6   No (ComentarioPrincipal)               105386 non-null  object
#  7   LikesComentarioPrincipal               105386 non-null  float64
#  8   ReplicasTotalesComentarioPrincipal     105386 non-null  float64
#  9   FechaPublicacionComentarioPrincipal    105386 non-null  object
# ...

# %% [markdown]
# # Importamos respuestas de series de youtube

# %%
# ======================== OJO Modificar para cada serie ========================

pathRCM='/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/\
EscobarPatrondelMal/RespuestasComentarios/RESULTS-PAISCOMENTARIOS-Lematizado2022-09-11 17_18_01.217465(EscobarPatrondelMal).xlsx'

# ======================== OJO Modificar para cada serie ========================

dfRCM= pd.read_excel(pathRCM)
dfRCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67552 entries, 0 to 67551
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   idComentarioPrincipal                            67552 non-null  object
#  1   idComentarioRespuesta                            67552 non-null  object
#  2   TextoComentarioRespuesta                         67550 non-null  object
#  3   FP (ComentarioRespuesta)                         0 non-null      float64
#  4   IM (ComentarioRespuesta)                         0 non-null      float64
#  5   CH (ComentarioRespuesta)                         0 non-null      float64
#  6   No (ComentarioRespuesta)                         0 non-null      float64
#  7   ComentarioRespuestaModificado                    67552 non-null  object
#  8   emojisComentarioRespuesta                        67552 non-null  object
# ...

# %%
dfRCM=dfRCM.drop(columns=['ComentarioRespuestaModificado','emojisComentarioRespuesta','URLsComentarioRespuesta','hashtagsComentarioRespuesta','MencionesComentarioRespuesta'\
                          ,'URLAutorCanalComentarioRespuesta','idAutorCanalComentarioRespuesta','CalificacionEspectadorComentarioRespuesta','CalificarComentarioRespuesta','SolicitudComentarioRespuesta','ComentarioRespuestaModificadoLematizadoProfundo'])

# %%
dfRCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67552 entries, 0 to 67551
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idComentarioPrincipal                  67552 non-null  object
#  1   idComentarioRespuesta                  67552 non-null  object
#  2   TextoComentarioRespuesta               67550 non-null  object
#  3   FP (ComentarioRespuesta)               0 non-null      float64
#  4   IM (ComentarioRespuesta)               0 non-null      float64
#  5   CH (ComentarioRespuesta)               0 non-null      float64
#  6   No (ComentarioRespuesta)               0 non-null      float64
#  7   LikesComentarioRespuesta               67552 non-null  float64
#  8   FechaPublicacionComentarioRespuesta    67552 non-null  object
#  9   FechaActualizacionComentarioRespuesta  67552 non-null  object
# ...

# %%
dfRCM=dfRCM.assign(UtilComentarioRespuestaSi_No="") # solo para narcos

# %%
dfRCM=dfRCM.assign(UtilComentarioRespuestaSi_No="",ComentarioRespuesta_ComentarioGumelab="")

# %%
dfRCM
# Out:
#             idComentarioPrincipal  \
# 0      Ugz-p0n67DppB3RyeOx4AaABAg
# 1      UgyRC-WEFsifvxz5kYp4AaABAg
# 2      UgyRC-WEFsifvxz5kYp4AaABAg
# 3      Ugz7L2y6Kub5RTQlMW94AaABAg
# 4      UgyDrlUQFHVEu_rug1p4AaABAg
# ...                           ...
# 67547        Uggiz61X0vPWMngCoAEC
# 67548        Uggiz61X0vPWMngCoAEC
# 67549        Uggiz61X0vPWMngCoAEC
# 67550        Uggiz61X0vPWMngCoAEC
# 67551  UgyhMXTUxR-ThYhzUCF4AaABAg
#
#                                    idComentarioRespuesta  \
# 0      Ugz-p0n67DppB3RyeOx4AaABAg.97RN40l2RPl9Ak2lKcATLF
# 1      UgyRC-WEFsifvxz5kYp4AaABAg.9XBs5IY10Xm9XBu1zli3He
# 2      UgyRC-WEFsifvxz5kYp4AaABAg.9XBs5IY10Xm9XBt83e3955
# 3      Ugz7L2y6Kub5RTQlMW94AaABAg.9f1OZFi2iKo9fZ4JpRQPBu
# 4      UgyDrlUQFHVEu_rug1p4AaABAg.9el2E9iGlr-9ewx2EvREs1
# ...                                                  ...
# 67547        Uggiz61X0vPWMngCoAEC.858EtGbHwz58oxwyDb4cOF
# 67548        Uggiz61X0vPWMngCoAEC.858EtGbHwz58oxwqJeRDbp
# ...

# %%
dfRCM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67552 entries, 0 to 67551
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   idComentarioPrincipal                  67552 non-null  object
#  1   idComentarioRespuesta                  67552 non-null  object
#  2   TextoComentarioRespuesta               67550 non-null  object
#  3   FP (ComentarioRespuesta)               0 non-null      float64
#  4   IM (ComentarioRespuesta)               0 non-null      float64
#  5   CH (ComentarioRespuesta)               0 non-null      float64
#  6   No (ComentarioRespuesta)               0 non-null      float64
#  7   LikesComentarioRespuesta               67552 non-null  float64
#  8   FechaPublicacionComentarioRespuesta    67552 non-null  object
#  9   FechaActualizacionComentarioRespuesta  67552 non-null  object
# ...

# %% [markdown]
# # Uniendo Comentarios a Videos

# %%
resultVC = pd.merge(left=dfVD, right=dfCM, how="left", left_on='idVideo', right_on='idVideo')
resultVC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106182 entries, 0 to 106181
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   idVideo                                106182 non-null  object
#  1   TituloVideo                            106182 non-null  object
#  2   DescripcionVideo                       96614 non-null   object
#  3   FechaPublicacionVideo                  106182 non-null  object
#  4   VistasVideo                            106182 non-null  int64
#  5   LikesVideo                             106098 non-null  float64
#  6   ComentariosVideo                       106173 non-null  float64
#  7   ConsultaVideo                          106182 non-null  object
#  8   PaisVideo                              106182 non-null  object
#  9   UtilVideoSi_No                         48197 non-null   object
# ...

# %% [markdown]
# # Uniendo Respuestas a Comentarios

# %%
resultRVC = pd.merge(left=resultVC, right=dfRCM, how="left", left_on='idComentarioPrincipal', right_on='idComentarioPrincipal')
resultRVC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154161 entries, 0 to 154160
# Data columns (total 38 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   idVideo                                154161 non-null  object
#  1   TituloVideo                            154161 non-null  object
#  2   DescripcionVideo                       140317 non-null  object
#  3   FechaPublicacionVideo                  154161 non-null  object
#  4   VistasVideo                            154161 non-null  int64
#  5   LikesVideo                             154045 non-null  float64
#  6   ComentariosVideo                       154152 non-null  float64
#  7   ConsultaVideo                          154161 non-null  object
#  8   PaisVideo                              154161 non-null  object
#  9   UtilVideoSi_No                         70064 non-null   object
# ...

# %% [markdown]
# # Exportando a excel (Para cada Serie)

# %%
today = str(date.today())

# ===== OJO Cambiar para cada Serie =====

PATH_TO_SAVE_SEARCHES = '/content/drive/MyDrive/AI-GUMELAB/CognASSISTANT-1/SEARCHES/ResultadosYoutubeFinales2023/BancoDatosYoutube/EscobarPatrondelMal/'

# ===== OJO Cambiar para cada Serie =====

PATH_TO_DIR_0 = PATH_TO_SAVE_SEARCHES 
if os.path.exists(PATH_TO_DIR_0) == False:
  os.mkdir(PATH_TO_DIR_0)
file_nameL = 'BancoDatos'+str(datetime.now())

# %%
resultRVC.to_excel(PATH_TO_DIR_0+'/'+'RESULTS-'+file_nameL+'.xlsx', index=False)

# %%
resultRVC
# Out:
#             idVideo                                        TituloVideo  \
# 0       KyqdbQW3pcg  Quien es quien en la la serie escobar el patro...
# 1       VfW5EtBscbc  Opinión Serie Pablo Escobar, ''el patrón del m...
# 2       k2TeK3a2Y2E             Série Pablo Escobar " Patron del Mal "
# 3       i7RBeP5kzTE      Intro serie pablo escobar "el patron del mal"
# 4       uymQfLPZZAQ  Representación serie Pablo Escobar el patrón d...
# ...             ...                                                ...
# 154156  4dfaXMxefgs  Higuita enfrenta al ayudante de Pablo Escobar ...
# 154157  4dfaXMxefgs  Higuita enfrenta al ayudante de Pablo Escobar ...
# 154158  4dfaXMxefgs  Higuita enfrenta al ayudante de Pablo Escobar ...
# 154159  4dfaXMxefgs  Higuita enfrenta al ayudante de Pablo Escobar ...
# 154160  4dfaXMxefgs  Higuita enfrenta al ayudante de Pablo Escobar ...
#
#                                          DescripcionVideo  \
# ...
